# %%
from select import select
from tkinter import BROWSE
import pandas as pd
from pandas import DataFrame
from webbrowser import BaseBrowser
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from webdriver_manager.chrome import ChromeDriverManager

# %%
#브라우저 꺼짐 방지
chrome_option=Options()
chrome_option.add_experimental_option("detach",True)

#불필요한 에러 메시지 없애기
chrome_option.add_experimental_option("excludeSwitches",["enable-logging"])

driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
# 웹페이지 해당 주소 이동
driver.implicitly_wait(5)#웹페이지가 로딩 될때까지 5초는 기다림
# Out:
# C:\Users\dahun\AppData\Local\Temp\ipykernel_20836\2781865031.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)

# %%
driver.get("https://store.steampowered.com/category/action/?flavor=contenthub_topsellers")
driver.implicitly_wait(10)#로딩이 끝날 때까지 10초 기다림ex

driver.find_element(By.CSS_SELECTOR,"#language_pulldown").click()
driver.find_element(By.CSS_SELECTOR,"#language_dropdown > div > a:nth-child(4)").click()

# %%
# 스크롤 전 높이
before_h = driver.execute_script("return window.scrollY")

# 무한 스크롤
while True:

        # 맨아래로 스크롤
        driver.find_element(By.CSS_SELECTOR,"body").send_keys(Keys.END)


        # 스크롤 후 높이 채크
        after_h=driver.execute_script("return window.scrollY")

        if after_h==before_h:
                break
        before_h=after_h

# %%
Game2=driver.find_elements(By.CLASS_NAME,"salepreviewwidgets_SaleItemBrowserRow_y9MSd")
Game2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="333a494f60b27932e8869a3164d048c8", element="ab9c3e97-ec88-4971-9185-b6a9920b9142")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="333a494f60b27932e8869a3164d048c8", element="d50f8acf-a328-4986-bcdd-0db676be2ef3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="333a494f60b27932e8869a3164d048c8", element="eeeb59e4-49ab-4260-b48d-649029804886")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="333a494f60b27932e8869a3164d048c8", element="56ce4602-6286-485a-9973-ea8ee32bcde7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="333a494f60b27932e8869a3164d048c8", element="7d2ff9d2-013b-400d-8a5d-94ca4c2632b8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="333a494f60b27932e8869a3164d048c8", element="5bd97d5b-adf1-4514-8a34-0591eff3b7e4")>,
# ...

# %%
Game3=list(map(lambda x : x.text.split('\n'),Game2))
Game3
# Out:
# [['MONSTER HUNTER RISE',
#   '2022년 1월 13일',
#   '매우 긍정적',
#   '| 사용자 평가 34,413개',
#   '-50%',
#   '₩ 48,400',
#   '₩ 24,200'],
#  ['콜 오브 듀티®: 모던 워페어 II 2022',
#   '2022년 10월 28일',
#   '복합적',
#   '| 사용자 평가 81,939개',
#   '무료 플레이'],
#  ['PUBG: BATTLEGROUNDS',
#   '2017년 12월 21일',
#   '복합적',
#   '| 사용자 평가 2,096,938개',
#   '무료 플레이'],
#  ['APEX 레전드™', '2020년 11월 5일', '매우 긍정적', '| 사용자 평가 530,132개', '무료 플레이'],
#  ['MONSTER HUNTER: WORLD',
#   '2018년 8월 10일',
#   '매우 긍정적',
#   '| 사용자 평가 220,085개',
#   '-50%',
#   '₩ 34,900',
#   '₩ 17,450'],
#  ['COUNTER-STRIKE: GLOBAL OFFENSIVE',
#   '2012년 8월 22일',
#   '매우 긍정적',
#   '| 사용자 평가 6,742,826개',
#   '무료 플레이'],
#  ['GRAND THEFT AUTO V',
#   '오픈 월드액션멀티플레이어범죄자동차 시뮬레이션',
#   '2015년 4월 14일',
#   '매우 긍정적',
#   '| 사용자 평가 1,305,366개',
#   '-25%',
#   '₩ 44,000',
#   '₩ 33,000'],
#  ['WARFRAME',
#   '무료 플레이액션 RPG약탈 슈팅RPG액션',
#   '매우 긍정적',
#   '| 사용자 평가 511,308개',
#   '무료 플레이'],
#  ['GOD OF WAR',
#   '액션싱글 플레이어어드벤처풍부한 스토리신화',
#   '2022년 1월 15일',
# ...

# %%
Game3=list(map(lambda x : x.text.split('\n'),Game2))

for i in Game3:
    if "년" in i[2] and "월" in i[2] and "일" in i[2] :
        del i[2]
        
#이름
name=[]
jan=[]
evaluation=[]
user=[]
for i in Game3:
    name.append(i[0])
    jan.append(i[1])
    evaluation.append(i[2])
    user.append(i[3])

data={'Game Name':name,'장르':jan,'평가':evaluation,'user 평가': user}
action=pd.DataFrame(data)

action
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 Game3=list(map(lambda x : x.text.split('\n'),Game2))
#       3 for i in Game3:
#       4     if "년" in i[2] and "월" in i[2] and "일" in i[2] :
#
# Input In [7], in <lambda>(x)
# ----> 1 Game3=list(map(lambda x : x.text.split('\n'),Game2))
#       3 for i in Game3:
#       4     if "년" in i[2] and "월" in i[2] and "일" in i[2] :
#
# File ~\Anaconda3\envs\database\lib\site-packages\selenium\webdriver\remote\webelement.py:84, in WebElement.text(self)
#      81 @property
#      82 def text(self) -> str:
#      83     """The text of the element."""
# ---> 84     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#
# File ~\Anaconda3\envs\database\lib\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
# ...

# %%
#브라우저 꺼짐 방지
chrome_option=Options()
chrome_option.add_experimental_option("detach",True)

#불필요한 에러 메시지 없애기
chrome_option.add_experimental_option("excludeSwitches",["enable-logging"])

driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
# 웹페이지 해당 주소 이동
driver.implicitly_wait(5)#웹페이지가 로딩 될때까지 5초는 기다림


driver.get("https://store.steampowered.com/tags/ko/RPG/")
driver.implicitly_wait(10)#로딩이 끝날 때까지 10초 기다림ex

driver.find_element(By.CSS_SELECTOR,"#language_pulldown").click()
driver.find_element(By.CSS_SELECTOR,"#language_dropdown > div > a:nth-child(4)").click()

# %%
Game3

# %%
# 스크롤 전 높이
before_h = driver.execute_script("return window.scrollY")

# 무한 스크롤
while True:

        # 맨아래로 스크롤
        driver.find_element(By.CSS_SELECTOR,"body").send_keys(Keys.END)


        # 스크롤 후 높이 채크
        after_h=driver.execute_script("return window.scrollY")

        if after_h==before_h:
                break
        before_h=after_h


Game2=driver.find_elements(By.CLASS_NAME,"salepreviewwidgets_SaleItemBrowserRow_y9MSd")
Game2


Game3=list(map(lambda x : x.text.split('\n'),Game2))

for i in Game3:
    if "년" in i[2] and "월" in i[2] and "일" in i[2] :
        del i[2]
        
#이름
name=[]
jan=[]
evaluation=[]
user=[]
for i in Game3:
    name.append(i[0])
    jan.append(i[1])
    evaluation.append(i[2])
    user.append(i[3])

data={'Game Name':name,'장르':jan,'평가':evaluation,'user 평가': user}
RPG=pd.DataFrame(data)

RPG
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [12], in <cell line: 23>()
#      19 Game2=driver.find_elements(By.CLASS_NAME,"salepreviewwidgets_SaleItemBrowserRow_y9MSd")
#      20 Game2
# ---> 23 Game3=list(map(lambda x : x.text.split('\n'),Game2))
#      25 for i in Game3:
#      26     if "년" in i[2] and "월" in i[2] and "일" in i[2] :
#
# Input In [12], in <lambda>(x)
#      19 Game2=driver.find_elements(By.CLASS_NAME,"salepreviewwidgets_SaleItemBrowserRow_y9MSd")
#      20 Game2
# ---> 23 Game3=list(map(lambda x : x.text.split('\n'),Game2))
#      25 for i in Game3:
#      26     if "년" in i[2] and "월" in i[2] and "일" in i[2] :
#
# File ~\Anaconda3\envs\database\lib\site-packages\selenium\webdriver\remote\webelement.py:84, in WebElement.text(self)
#      81 @property
#      82 def text(self) -> str:
#      83     """The text of the element."""
# ...

# %%
#브라우저 꺼짐 방지
chrome_option=Options()
chrome_option.add_experimental_option("detach",True)

#불필요한 에러 메시지 없애기
chrome_option.add_experimental_option("excludeSwitches",["enable-logging"])

driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
# 웹페이지 해당 주소 이동
driver.implicitly_wait(5)#웹페이지가 로딩 될때까지 5초는 기다림


driver.get("https://store.steampowered.com/tags/ko/%EC%9D%B8%EB%94%94/")
driver.implicitly_wait(10)#로딩이 끝날 때까지 10초 기다림ex

driver.find_element(By.CSS_SELECTOR,"#language_pulldown").click()
driver.find_element(By.CSS_SELECTOR,"#language_dropdown > div > a:nth-child(4)").click()

# 스크롤 전 높이
before_h = driver.execute_script("return window.scrollY")

# 무한 스크롤
while True:

        # 맨아래로 스크롤
        driver.find_element(By.CSS_SELECTOR,"body").send_keys(Keys.END)


        # 스크롤 후 높이 채크
        after_h=driver.execute_script("return window.scrollY")

        if after_h==before_h:
                break
        before_h=after_h


Game2=driver.find_elements(By.CLASS_NAME,"salepreviewwidgets_SaleItemBrowserRow_y9MSd")
Game2


Game3=list(map(lambda x : x.text.split('\n'),Game2))

for i in Game3:
    if "년" in i[2] and "월" in i[2] and "일" in i[2] :
        del i[2]
        
#이름
name=[]
jan=[]
evaluation=[]
user=[]
for i in Game3:
    name.append(i[0])
    jan.append(i[1])
    evaluation.append(i[2])
    user.append(i[3])

data={'Game Name':name,'장르':jan,'평가':evaluation,'user 평가': user}
indi=pd.DataFrame(data)

indi
# Out:
# C:\Users\dahun\AppData\Local\Temp\ipykernel_20836\1309781693.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
#                         Game Name                             장르         평가  \
# 0                  RISK OF RAIN 2                   2020년 8월 11일  압도적으로 긍정적
# 1                  STARDEW VALLEY                   2016년 2월 27일  압도적으로 긍정적
# 2                    FOR THE KING             RPG오픈 월드전략온라인 협동턴제     매우 긍정적
# 3                HUMAN: FALL FLAT                   협동유머퍼즐어드벤처물리     매우 긍정적
# 4                  SLAY THE SPIRE    로그라이크 덱빌딩카드 게임카드 배틀로그라이크덱빌딩  압도적으로 긍정적
# 5                 PROJECT ZOMBOID     생존좀비오픈 월드오픈 월드 생존 제작멀티플레이어     매우 긍정적
# 6   THE BINDING OF ISAAC: REBIRTH     액션 로그라이크로그라이크인디리플레이 가치고난이도  압도적으로 긍정적
# 7                 THE PAST WITHIN       미스터리협동온라인 협동비동기 멀티플레이어공포     매우 긍정적
# ...

# %%
#브라우저 꺼짐 방지
chrome_option=Options()
chrome_option.add_experimental_option("detach",True)

#불필요한 에러 메시지 없애기
chrome_option.add_experimental_option("excludeSwitches",["enable-logging"])

driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
# 웹페이지 해당 주소 이동
driver.implicitly_wait(5)#웹페이지가 로딩 될때까지 5초는 기다림


driver.get("https://store.steampowered.com/tags/ko/%EC%96%B4%EB%93%9C%EB%B2%A4%EC%B2%98/")
driver.implicitly_wait(10)#로딩이 끝날 때까지 10초 기다림ex

driver.find_element(By.CSS_SELECTOR,"#language_pulldown").click()
driver.find_element(By.CSS_SELECTOR,"#language_dropdown > div > a:nth-child(4)").click()

# 스크롤 전 높이
before_h = driver.execute_script("return window.scrollY")

# 무한 스크롤
while True:

        # 맨아래로 스크롤
        driver.find_element(By.CSS_SELECTOR,"body").send_keys(Keys.END)


        # 스크롤 후 높이 채크
        after_h=driver.execute_script("return window.scrollY")

        if after_h==before_h:
                break
        before_h=after_h


Game2=driver.find_elements(By.CLASS_NAME,"salepreviewwidgets_SaleItemBrowserRow_y9MSd")
Game2


Game3=list(map(lambda x : x.text.split('\n'),Game2))

for i in Game3:
    if "년" in i[2] and "월" in i[2] and "일" in i[2] :
        del i[2]
        
#이름
name=[]
jan=[]
evaluation=[]
user=[]
for i in Game3:
    name.append(i[0])
    jan.append(i[1])
    evaluation.append(i[2])
    user.append(i[3])

data={'Game Name':name,'장르':jan,'평가':evaluation,'user 평가': user}
advan=pd.DataFrame(data)

advan
# Out:
# C:\Users\dahun\AppData\Local\Temp\ipykernel_20836\2185255593.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
#                          Game Name                               장르  \
# 0                        데이브 더 다이버              액션 어드벤처경영픽셀 그래픽탐험수중
# 1            MONSTER HUNTER: WORLD               협동멀티플레이어액션오픈 월드RPG
# 2                       토치라이트:인피니트             RPG액션 RPG약탈핵 앤 슬래시액션
# 3         DYING LIGHT 2 STAY HUMAN                   협동파쿠르좀비오픈 월드탐험
# 4                      CORE KEEPER  샌드박스픽셀 그래픽오픈 월드 생존 제작온라인 협동어드벤처
# 5                        타워 오브 판타지                   오픈 월드RPG액션3D협동
# 6   MONSTER HUNTER WORLD: ICEBORNE                액션멀티플레이어오픈 월드협동사냥
# 7                        ASTRONEER       멀티플레이어오픈 월드오픈 월드 생존 제작우주생존
# 8               GRAND THEFT AUTO V         오픈 월드액션멀티플레이어범죄자동차 시뮬레이션
# ...

# %%
#브라우저 꺼짐 방지
chrome_option=Options()
chrome_option.add_experimental_option("detach",True)

#불필요한 에러 메시지 없애기
chrome_option.add_experimental_option("excludeSwitches",["enable-logging"])

driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
# 웹페이지 해당 주소 이동
driver.implicitly_wait(5)#웹페이지가 로딩 될때까지 5초는 기다림


driver.get("https://store.steampowered.com/tags/ko/%EC%BA%90%EC%A3%BC%EC%96%BC/")
driver.implicitly_wait(10)#로딩이 끝날 때까지 10초 기다림ex

driver.find_element(By.CSS_SELECTOR,"#language_pulldown").click()
driver.find_element(By.CSS_SELECTOR,"#language_dropdown > div > a:nth-child(4)").click()

# 스크롤 전 높이
before_h = driver.execute_script("return window.scrollY")

# 무한 스크롤
while True:

        # 맨아래로 스크롤
        driver.find_element(By.CSS_SELECTOR,"body").send_keys(Keys.END)


        # 스크롤 후 높이 채크
        after_h=driver.execute_script("return window.scrollY")

        if after_h==before_h:
                break
        before_h=after_h


Game2=driver.find_elements(By.CLASS_NAME,"salepreviewwidgets_SaleItemBrowserRow_y9MSd")
Game2


Game3=list(map(lambda x : x.text.split('\n'),Game2))

for i in Game3:
    if "년" in i[2] and "월" in i[2] and "일" in i[2] :
        del i[2]
        
#이름
name=[]
jan=[]
evaluation=[]
user=[]
for i in Game3:
    name.append(i[0])
    jan.append(i[1])
    evaluation.append(i[2])
    user.append(i[3])

data={'Game Name':name,'장르':jan,'평가':evaluation,'user 평가': user}
casual=pd.DataFrame(data)

casual
# Out:
# C:\Users\dahun\AppData\Local\Temp\ipykernel_20836\4287016354.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
#                                    Game Name                               장르  \
# 0                            DJMAX RESPECT V                     리듬캐주얼액션음악스포츠
# 1                                 GRANDCHASE                액션PvPPvE액션 RPG캐주얼
# 2                        FREESTYLEFOOTBALL R                  MMOPvP스포츠축구MOBA
# 3                           CITIES: SKYLINES                 도시 건설시뮬레이션건설경영전략
# 4                                       마블스냅               전략카드 배틀PvP카드 게임캐주얼
# 5                             STARDEW VALLEY  농장 시뮬레이션생활 시뮬레이션픽셀 그래픽RPG멀티플레이어
# 6                                    BROTATO   액션 로그라이크로그라이트아레나 슈팅탄막 슈팅탑다운 슈팅
# 7             MARVEL’S SPIDER-MAN REMASTERED         슈퍼 히어로액션오픈 월드싱글 플레이어어드벤처
# ...

# %%
#브라우저 꺼짐 방지
chrome_option=Options()
chrome_option.add_experimental_option("detach",True)

#불필요한 에러 메시지 없애기
chrome_option.add_experimental_option("excludeSwitches",["enable-logging"])

driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
# 웹페이지 해당 주소 이동
driver.implicitly_wait(5)#웹페이지가 로딩 될때까지 5초는 기다림


driver.get("https://store.steampowered.com/tags/ko/%EC%A0%84%EB%9E%B5/")
driver.implicitly_wait(10)#로딩이 끝날 때까지 10초 기다림ex

driver.find_element(By.CSS_SELECTOR,"#language_pulldown").click()
driver.find_element(By.CSS_SELECTOR,"#language_dropdown > div > a:nth-child(4)").click()

# 스크롤 전 높이
before_h = driver.execute_script("return window.scrollY")

# 무한 스크롤
while True:

        # 맨아래로 스크롤
        driver.find_element(By.CSS_SELECTOR,"body").send_keys(Keys.END)


        # 스크롤 후 높이 채크
        after_h=driver.execute_script("return window.scrollY")

        if after_h==before_h:
                break
        before_h=after_h


Game2=driver.find_elements(By.CLASS_NAME,"salepreviewwidgets_SaleItemBrowserRow_y9MSd")
Game2


Game3=list(map(lambda x : x.text.split('\n'),Game2))

for i in Game3:
    if "년" in i[2] and "월" in i[2] and "일" in i[2] :
        del i[2]
        
#이름
name=[]
jan=[]
evaluation=[]
user=[]
for i in Game3:
    name.append(i[0])
    jan.append(i[1])
    evaluation.append(i[2])
    user.append(i[3])

data={'Game Name':name,'장르':jan,'평가':evaluation,'user 평가': user}
stra=pd.DataFrame(data)

stra
# Out:
# C:\Users\dahun\AppData\Local\Temp\ipykernel_20836\1293101255.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
#                            Game Name                          장르         평가  \
# 0                PUBG: BATTLEGROUNDS       생존슈팅멀티플레이어배틀 로얄1인칭 슈팅        복합적
# 1       SID MEIER’S CIVILIZATION® VI      전략턴제 전략역사멀티플레이어싱글 플레이어     매우 긍정적
# 2              FOOTBALL MANAGER 2023        시뮬레이션스포츠실시간 전술경영e스포츠     매우 긍정적
# 3                  AGAINST THE STORM   전략기지 건설도시 건설시뮬레이션개척 시뮬레이션  압도적으로 긍정적
# 4              YU-GI-OH! MASTER DUEL  카드 게임무료 플레이전략트레이딩 카드 게임PvP    대체로 긍정적
# 5                   CITIES: SKYLINES            도시 건설시뮬레이션건설경영전략     매우 긍정적
# 6   COUNTER-STRIKE: GLOBAL OFFENSIVE          1인칭 슈팅슈팅멀티플레이어경쟁액션     매우 긍정적
# 7                          컨커러스 블레이드            전략MMO무료 플레이RPG액션        복합적
# ...

# %%
#브라우저 꺼짐 방지
chrome_option=Options()
chrome_option.add_experimental_option("detach",True)

#불필요한 에러 메시지 없애기
chrome_option.add_experimental_option("excludeSwitches",["enable-logging"])

driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
# 웹페이지 해당 주소 이동
driver.implicitly_wait(5)#웹페이지가 로딩 될때까지 5초는 기다림


driver.get("https://store.steampowered.com/tags/ko/%EA%B3%B5%ED%8F%AC/")
driver.implicitly_wait(10)#로딩이 끝날 때까지 10초 기다림ex

driver.find_element(By.CSS_SELECTOR,"#language_pulldown").click()
driver.find_element(By.CSS_SELECTOR,"#language_dropdown > div > a:nth-child(4)").click()

# 스크롤 전 높이
before_h = driver.execute_script("return window.scrollY")

# 무한 스크롤
while True:

        # 맨아래로 스크롤
        driver.find_element(By.CSS_SELECTOR,"body").send_keys(Keys.END)


        # 스크롤 후 높이 채크
        after_h=driver.execute_script("return window.scrollY")

        if after_h==before_h:
                break
        before_h=after_h


Game2=driver.find_elements(By.CLASS_NAME,"salepreviewwidgets_SaleItemBrowserRow_y9MSd")
Game2


Game3=list(map(lambda x : x.text.split('\n'),Game2))

for i in Game3:
    if "년" in i[2] and "월" in i[2] and "일" in i[2] :
        del i[2]
        
#이름
name=[]
jan=[]
evaluation=[]
user=[]
for i in Game3:
    name.append(i[0])
    jan.append(i[1])
    evaluation.append(i[2])
    user.append(i[3])

data={'Game Name':name,'장르':jan,'평가':evaluation,'user 평가': user}
horr=pd.DataFrame(data)

horr
# Out:
# C:\Users\dahun\AppData\Local\Temp\ipykernel_20836\1374705937.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
#                        Game Name                          장르         평가  \
# 0       DYING LIGHT 2 STAY HUMAN              협동파쿠르좀비오픈 월드탐험    대체로 긍정적
# 1               DEAD BY DAYLIGHT       공포생존 공포멀티플레이어온라인 협동생존     매우 긍정적
# 2                THE PAST WITHIN    미스터리협동온라인 협동비동기 멀티플레이어공포     매우 긍정적
# 3          DON'T STARVE TOGETHER    탐험오픈 월드 생존 제작생존샌드박스로그라이트  압도적으로 긍정적
# 4                   PHASMOPHOBIA      공포온라인 협동멀티플레이어심리적 공포협동  압도적으로 긍정적
# 5                     THE FOREST    오픈 월드 생존 제작생존오픈 월드공포크래프팅  압도적으로 긍정적
# 6              BIOHAZARD VILLAGE         생존 공포공포1인칭싱글 플레이어액션  압도적으로 긍정적
# 7                       GROUNDED  생존멀티플레이어기지 건설협동오픈 월드 생존 제작     매우 긍정적
# ...

# %%
RPG

# %%
indi

# %%
casual

# %%
horr

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd
db_connection_str = 'mysql+pymysql://database:1234@localhost:3306/my_list'
db_connection = create_engine(db_connection_str)
conn = db_connection.connect()
indi.to_sql(name='action', con=db_connection, if_exists='append',index=False)
# Out:
# 12

# %%
SQL_URL='mysql://database:1234@localhost:3306/my_list'
engine = sqlalchemy.create_engine(SQL_URL,echo=False)

# %%
import pymysql
import pandas as pd
import sqlalchemy

# %%
conn=pymysql.connect(host='127.0.0.1',user='database',password='1234',db='my_list',charset='utf8')

# %%
# !pip install mariadb
# !pip install sqlalchemy

# %%
# !pip install mysql

# %%
action

# %%
action.to_sql(name='action',con=engine,index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 action.to_sql(name='action',con=engine,index=False)
#
# NameError: name 'action' is not defined

# %%
advan.to_sql(name='advan',con=engine,index=False)
casual.to_sql(name='casual',con=engine,index=False)
horr.to_sql(name='horr',con=engine,index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 advan.to_sql(name='advan',con=engine,index=False)
#       2 casual.to_sql(name='casual',con=engine,index=False)
#       3 horr.to_sql(name='horr',con=engine,index=False)
#
# NameError: name 'advan' is not defined

# %%
RPG.to_sql(name='RPG',con=engine,index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 RPG.to_sql(name='RPG',con=engine,index=False)
#
# NameError: name 'RPG' is not defined

# %%
indi.to_sql(name='indi',con=engine,index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 indi.to_sql(name='indi',con=engine,index=False)
#
# NameError: name 'indi' is not defined
