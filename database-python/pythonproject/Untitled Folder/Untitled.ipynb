# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/dahun/Desktop/상가(상권)정보_의료기관_201909.csv")
# Out:
# C:\Users\dahun\AppData\Local\Temp\ipykernel_17388\3406300381.py:1: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("C:/Users/dahun/Desktop/상가(상권)정보_의료기관_201909.csv")

# %%
df
# Out:
#          상가업소번호           상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  상권업종중분류명  \
# 0      19956873        하나산부인과   NaN         S       의료       S01        병원
# 1      20024149      타워광명내과의원   NaN         S       의료       S01        병원
# 2      20152277     조정현신경외과의원   NaN         S       의료       S01        병원
# 3      20350610      한귀원정신과의원   NaN         S       의료       S01        병원
# 4      20364049     더블유스토어수지점   수지점         S       의료       S02    약국/한약방
# ...         ...           ...   ...       ...      ...       ...       ...
# 91330  16196725         온누리약국   베스트         S       의료       S02    약국/한약방
# 91331  16192180            리원  봄산후조         S       의료       S07  의료관련서비스업
# 91332  16127538       참좋은요양병원   NaN         S       의료       S01        병원
# 91333  16108681       경희중앙한의원   NaN         S       의료       S01        병원
# 91334  16109073  천안김안과천안역본점의원   NaN         S       의료       S01        병원
#
# ...

# %%
df.to_csv("houseprice.csv",encoding="utf-8-sig")

# %%
df.groupby('상권업종소분류명').get_group('약국').groupby('시도명').count()["상권업종소분류명"].sort_
# Out:
# 시도명
# 강원도         729
# 경기도        4510
# 경상남도       1017
# 경상북도        915
# 광주광역시       691
# 대구광역시       870
# 대전광역시       603
# 부산광역시      1130
# 서울특별시      3579
# 세종특별자치시      99
# 울산광역시       362
# 인천광역시      1002
# 전라남도        811
# 전라북도        862
# 제주특별자치도     226
# 충청남도        830
# 충청북도        648
# Name: 상권업종소분류명, dtype: int64

# %%
df.groupby('상권업종소분류명').get_group('동물병원').groupby('시도명').count()["상권업종소분류명"].sort_index()
# Out:
# 시도명
# 강원도         85
# 경기도        992
# 경상남도       161
# 경상북도       165
# 광주광역시       71
# 대구광역시      119
# 대전광역시       77
# 부산광역시      153
# 서울특별시      557
# 세종특별자치시     13
# 울산광역시       61
# 인천광역시      193
# 전라남도        77
# 전라북도       111
# 제주특별자치도     46
# 충청남도       131
# 충청북도        75
# Name: 상권업종소분류명, dtype: int64

# %%
a=df.groupby('상권업종소분류명').get_group('피부과').groupby('시도명').get_group('서울특별시').groupby('시군구명')["상권업종소분류명"].count()
a
# Out:
# 시군구명
# 강남구     159
# 강동구      15
# 강북구       1
# 강서구      15
# 관악구       8
# 광진구      16
# 구로구       5
# 금천구       1
# 노원구       9
# 도봉구       2
# 동대문구     11
# 동작구       9
# 마포구      15
# 서대문구     10
# 서초구      73
# 성동구       3
# 성북구      14
# 송파구      18
# 양천구      12
# 영등포구     13
# 용산구       7
# 은평구      13
# 종로구       3
# 중구       12
# 중랑구       6
# Name: 상권업종소분류명, dtype: int64

# %%
b=df.groupby('상권업종소분류명').get_group('정형/성형외과').groupby('시도명').get_group('서울특별시').groupby('시군구명')["상권업종소분류명"].count()
b
# Out:
# 시군구명
# 강남구     444
# 강동구      22
# 강북구      11
# 강서구      23
# 관악구       9
# 광진구      21
# 구로구      12
# 금천구       8
# 노원구      17
# 도봉구       3
# 동대문구     16
# 동작구       5
# 마포구      25
# 서대문구     19
# 서초구     127
# 성동구      14
# 성북구      14
# 송파구      30
# 양천구      14
# 영등포구     26
# 용산구       3
# 은평구      18
# 종로구       8
# 중구       19
# 중랑구      15
# Name: 상권업종소분류명, dtype: int64

# %%
# Out:
# 시도명
# 강원도         2634
# 경기도        21374
# 경상남도        4973
# 경상북도        4141
# 광주광역시       3214
# 대구광역시       4597
# 대전광역시       3067
# 부산광역시       6473
# 서울특별시      18943
# 세종특별자치시      353
# 울산광역시       1997
# 인천광역시       4722
# 전라남도        3224
# 전라북도        3894
# 제주특별자치도     1095
# 충청남도        3578
# 충청북도        2677
# Name: 상권업종소분류명, dtype: int64

# %%
((a+b)/df.groupby('시도명').get_group('서울특별시').groupby('시군구명')["상권업종소분류명"].count()).sort_index().round(2)
# Out:
# 시군구명
# 강남구     0.19
# 강동구     0.05
# 강북구     0.03
# 강서구     0.05
# 관악구     0.03
# 광진구     0.04
# 구로구     0.04
# 금천구     0.03
# 노원구     0.04
# 도봉구     0.01
# 동대문구    0.02
# 동작구     0.03
# 마포구     0.06
# 서대문구    0.05
# 서초구     0.13
# 성동구     0.04
# 성북구     0.04
# 송파구     0.05
# 양천구     0.05
# 영등포구    0.05
# 용산구     0.03
# 은평구     0.04
# 종로구     0.02
# 중구      0.05
# 중랑구     0.04
# Name: 상권업종소분류명, dtype: float64

# %%
df.groupby('시도명').get_group('서울특별시').groupby('시군구명')["상권업종소분류명"].count()
# Out:
# 시군구명
# 강남구     3120
# 강동구      703
# 강북구      396
# 강서구      799
# 관악구      578
# 광진구      935
# 구로구      451
# 금천구      303
# 노원구      741
# 도봉구      412
# 동대문구    1152
# 동작구      489
# 마포구      649
# 서대문구     543
# 서초구     1491
# 성동구      482
# 성북구      708
# 송파구     1021
# 양천구      574
# 영등포구     731
# 용산구      361
# 은평구      739
# 종로구      492
# 중구       576
# 중랑구      497
# Name: 상권업종소분류명, dtype: int64

# %%
# !pip install folium
# Out:
# ...
#      ---------------------------------------- 96.5/96.5 kB 5.8 MB/s eta 0:00:00
# ...

# %%
# Out:
# [129.040772964856,
#  127.746980976467,
#  126.780121523366,
#  127.460606294325,
#  128.295523973833,
#  127.074130486014,
#  128.965882995454,
#  126.734896909719,
#  127.068114853914,
#  129.072181463324,
#  128.053169465413,
#  128.281933535321,
#  128.270847074502,
#  129.167326276602,
#  128.115865497371,
#  127.140445260087,
#  127.272792469207,
#  126.850979847853,
#  126.800935591679,
#  126.776742491254,
#  127.21296693272,
#  127.930944766967,
#  128.624738724923,
#  127.020007824897,
#  129.106597785763,
#  127.138924136779,
#  127.888697911961,
#  126.815598549054,
#  127.444396714623,
#  127.444396714623,
#  126.727132308317,
#  126.869416772003,
#  129.088921136941,
#  129.079284575046,
#  129.260240912044,
#  127.352737262797,
#  126.897886933035,
#  129.059609982577,
#  127.312803332909,
#  127.34091595658,
#  126.936826198535,
#  128.607461541353,
#  129.042974081393,
#  126.925930596134,
#  126.844861738226,
#  126.887917001123,
#  127.163894671236,
# ...

# %%
c=df.groupby('상권업종소분류명').get_group('노인/치매병원')['경도'].to_list()
d=df.groupby('상권업종소분류명').get_group('노인/치매병원')['위도'].to_list()
m=folium.Map()
for i,j in zip(c,d):
    folium.Marker([j,i]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
