# %%
from select import select
from tkinter import BROWSE
from webbrowser import BaseBrowser
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from webdriver_manager.chrome import ChromeDriverManager

# %%
#브라우저 꺼짐 방지
chrome_option=Options()
chrome_option.add_experimental_option("detach",True)

#불필요한 에러 메시지 없애기
chrome_option.add_experimental_option("excludeSwitches",["enable-logging"])

# %%
driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)
# 웹페이지 해당 주소 이동
driver.implicitly_wait(5)#웹페이지가 로딩 될때까지 5초는 기다림
driver.maximize_window()#화면 최대화
driver.get("https://store.steampowered.com/category/action/?flavor=contenthub_topsellers")
driver.implicitly_wait(10)#로딩이 끝날 때까지 10초 기다림ex


driver.find_element(By.CSS_SELECTOR,"#language_pulldown").click()
driver.find_element(By.CSS_SELECTOR,"#language_dropdown > div > a:nth-child(4)").click()
# Out:
# C:\Users\dahun\AppData\Local\Temp\ipykernel_21708\2477585468.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='D:\pythonproject\chromedriver.exe',options=chrome_option)

# %%
Game2=driver.find_elements(By.CSS_SELECTOR,".salepreviewwidgets_SaleItemBrowserRow_y9MSd")
Game3=list(map(lambda x : x.text.split('\n'),Game2))
Game3
# Out:
# []

# %%
for i in Game3:
    if "년" in i[2] and "월" in i[2] and "일" in i[2] :
        del i[2]
Game3
Game2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="2d675be6-6bff-4daf-83c2-441f630809b7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="f1240a27-4e5d-48eb-a6c7-30b462bac626")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="65acd88b-0a0c-415c-bba1-ff6ede27dcc5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="7ab32bec-94d2-409d-a0cf-6fa210ab3913")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="433d5b11-24e8-4e96-a16d-dec862c5809a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="7928a856-2e33-40db-a1e5-203e02d45871")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="847e2248-8059-474b-9bc2-3033e88673b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="7a633adc-e73a-4261-a97f-05ed89e8fe37")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="14e9e755-f51a-4f51-b10d-504ae64d45a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="fd4fd219-d0c3-413b-b985-acc8a7801740")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="ed246bf1-bc9c-4cab-ab25-cabb18500704")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5a6deacc5bc619ce9d81d27013a52a1", element="943f237f-b5a2-4d9c-bf2d-59ded7efd7ce")>]

# %%
Game3
# Out:
# [['트라하 글로벌', '전투RPG액션협동MMORPG', '복합적', '| 사용자 평가 343개', '무료 플레이'],
#  ['콜 오브 듀티®: 모던 워페어 II 2022',
#   '1인칭 슈팅액션슈팅멀티플레이어군사',
#   '복합적',
#   '| 사용자 평가 41,352개',
#   '₩ 84,500'],
#  ['MOUNT & BLADE II: BANNERLORD',
#   '중세전략오픈 월드RPG전쟁',
#   '매우 긍정적',
#   '| 사용자 평가 157,472개',
#   '-20%',
#   '₩ 55,000',
#   '₩ 44,000'],
#  ['STAR OCEAN THE DIVINE FORCE',
#   'RPG액션 RPGJRPG액션여주인공',
#   '복합적',
#   '| 사용자 평가 581개',
#   '₩ 69,800'],
#  ['GOTHAM KNIGHTS',
#   '액션슈퍼 히어로오픈 월드온라인 협동액션 RPG',
#   '대체로 긍정적',
#   '| 사용자 평가 5,570개',
#   '₩ 68,800'],
#  ['VAMPIRE SURVIVORS',
#   '액션 로그라이크탄막 슈팅픽셀 그래픽로그라이트2D',
#   '압도적으로 긍정적',
#   '| 사용자 평가 125,034개',
#   '₩ 5,000'],
#  ['SIGNALIS', '생존 공포액션공상과학여주인공어드벤처', '압도적으로 긍정적', '| 사용자 평가 998개', '₩ 20,500'],
#  ['토치라이트:인피니트', 'RPG액션 RPG핵 앤 슬래시액션약탈', '복합적', '| 사용자 평가 2,878개', '무료 플레이'],
#  ['UNCHARTED™: 레거시 오브 시브즈 컬렉션',
#   '어드벤처액션 어드벤처싱글 플레이어풍부한 스토리3인칭',
#   '매우 긍정적',
#   '| 사용자 평가 2,665개',
#   '₩ 45,800'],
#  ['SUPER PEOPLE', '배틀 로얄슈팅생존액션MMO', '복합적', '| 사용자 평가 6,971개', '무료 플레이'],
#  ['ARMY OF RUIN',
#   '탄막 슈팅로그라이트탑다운슛뎀업캐주얼',
#   '매우 긍정적',
#   '| 사용자 평가 186개',
#   '-10%',
#   '₩ 4,400',
#   '₩ 3,960'],
#  ['BROTATO',
#   '액션 로그라이크로그라이트아레나 슈팅탄막 슈팅탑다운 슈팅',
#   '압도적으로 긍정적',
#   '| 사용자 평가 6,831개',
#   '₩ 5,500']]

# %%
#이름
name=[]
jan=[]
evaluation=[]
user=[]
for i in Game3:
    name.append(i[0])
    jan.append(i[1])
    evaluation.append(i[2])
    user.append(i[3])

# %%
name
# Out:
# ['트라하 글로벌',
#  '콜 오브 듀티®: 모던 워페어 II 2022',
#  'MOUNT & BLADE II: BANNERLORD',
#  'STAR OCEAN THE DIVINE FORCE',
#  'GOTHAM KNIGHTS',
#  'VAMPIRE SURVIVORS',
#  'SIGNALIS',
#  '토치라이트:인피니트',
#  'UNCHARTED™: 레거시 오브 시브즈 컬렉션',
#  'SUPER PEOPLE',
#  'ARMY OF RUIN',
#  'BROTATO']

# %%
jan
# Out:
# ['전투RPG액션협동MMORPG',
#  '1인칭 슈팅액션슈팅멀티플레이어군사',
#  '중세전략오픈 월드RPG전쟁',
#  'RPG액션 RPGJRPG액션여주인공',
#  '액션슈퍼 히어로오픈 월드온라인 협동액션 RPG',
#  '액션 로그라이크탄막 슈팅픽셀 그래픽로그라이트2D',
#  '생존 공포액션공상과학여주인공어드벤처',
#  'RPG액션 RPG핵 앤 슬래시액션약탈',
#  '어드벤처액션 어드벤처싱글 플레이어풍부한 스토리3인칭',
#  '배틀 로얄슈팅생존액션MMO',
#  '탄막 슈팅로그라이트탑다운슛뎀업캐주얼',
#  '액션 로그라이크로그라이트아레나 슈팅탄막 슈팅탑다운 슈팅']

# %%
evaluation
# Out:
# ['복합적',
#  '복합적',
#  '매우 긍정적',
#  '복합적',
#  '대체로 긍정적',
#  '압도적으로 긍정적',
#  '압도적으로 긍정적',
#  '복합적',
#  '매우 긍정적',
#  '복합적',
#  '매우 긍정적',
#  '압도적으로 긍정적']

# %%
user
# Out:
# ['| 사용자 평가 343개',
#  '| 사용자 평가 41,352개',
#  '| 사용자 평가 157,472개',
#  '| 사용자 평가 581개',
#  '| 사용자 평가 5,570개',
#  '| 사용자 평가 125,034개',
#  '| 사용자 평가 998개',
#  '| 사용자 평가 2,878개',
#  '| 사용자 평가 2,665개',
#  '| 사용자 평가 6,971개',
#  '| 사용자 평가 186개',
#  '| 사용자 평가 6,831개']

# %%
data={'Game Name':name,'장르':jan,'평가':evaluation,'user 평가': user}
frame=pd.DataFrame(data)

# %%
frame
# Out:
#                        Game Name                              장르         평가  \
# 0                        트라하 글로벌                 전투RPG액션협동MMORPG        복합적
# 1       콜 오브 듀티®: 모던 워페어 II 2022              1인칭 슈팅액션슈팅멀티플레이어군사        복합적
# 2   MOUNT & BLADE II: BANNERLORD                  중세전략오픈 월드RPG전쟁     매우 긍정적
# 3    STAR OCEAN THE DIVINE FORCE             RPG액션 RPGJRPG액션여주인공        복합적
# 4                 GOTHAM KNIGHTS       액션슈퍼 히어로오픈 월드온라인 협동액션 RPG    대체로 긍정적
# 5              VAMPIRE SURVIVORS      액션 로그라이크탄막 슈팅픽셀 그래픽로그라이트2D  압도적으로 긍정적
# 6                       SIGNALIS             생존 공포액션공상과학여주인공어드벤처  압도적으로 긍정적
# 7                     토치라이트:인피니트            RPG액션 RPG핵 앤 슬래시액션약탈        복합적
# 8     UNCHARTED™: 레거시 오브 시브즈 컬렉션    어드벤처액션 어드벤처싱글 플레이어풍부한 스토리3인칭     매우 긍정적
# 9                   SUPER PEOPLE                  배틀 로얄슈팅생존액션MMO        복합적
# 10                  ARMY OF RUIN             탄막 슈팅로그라이트탑다운슛뎀업캐주얼     매우 긍정적
# 11                       BROTATO  액션 로그라이크로그라이트아레나 슈팅탄막 슈팅탑다운 슈팅  압도적으로 긍정적
#
#               user 평가
# 0       | 사용자 평가 343개
# 1    | 사용자 평가 41,352개
# 2   | 사용자 평가 157,472개
# 3       | 사용자 평가 581개
# 4     | 사용자 평가 5,570개
# 5   | 사용자 평가 125,034개
# 6       | 사용자 평가 998개
# 7     | 사용자 평가 2,878개
# 8     | 사용자 평가 2,665개
# 9     | 사용자 평가 6,971개
# 10      | 사용자 평가 186개
# 11    | 사용자 평가 6,831개

# %%
tag=driver.find_elements(By.CLASS_NAME,"salepreviewwidgets_StoreSaleWidgetTags_3OSJs")

# %%
tag_list=list(map(lambda x : x.text.split('\n'),tag))
tag_list
# Out:
# [['전투RPG액션협동MMORPG'],
#  ['1인칭 슈팅액션슈팅멀티플레이어군사'],
#  ['중세전략오픈 월드RPG전쟁'],
#  ['RPG액션 RPGJRPG액션여주인공'],
#  ['액션슈퍼 히어로오픈 월드온라인 협동액션 RPG'],
#  ['액션 로그라이크탄막 슈팅픽셀 그래픽로그라이트2D'],
#  ['생존 공포액션공상과학여주인공어드벤처'],
#  ['RPG액션 RPG핵 앤 슬래시액션약탈'],
#  ['어드벤처액션 어드벤처싱글 플레이어풍부한 스토리3인칭'],
#  ['배틀 로얄슈팅생존액션MMO'],
#  ['탄막 슈팅로그라이트탑다운슛뎀업캐주얼'],
#  ['액션 로그라이크로그라이트아레나 슈팅탄막 슈팅탑다운 슈팅']]

# %%
tag_tag=[
"인디"
,"액션"
,"어드벤처"
,"캐주얼"
,"시뮬레이션"
,"RPG"
,"전략"
,"싱글 플레이어"
,"앞서 해보기"
,"무료 플레이"
,"2D"
,"분위기 있는"
,"3D"
,"풍부한 스토리"
,"판타지"
,"멀티플레이어"
,"MMO"
,"퍼즐"
,"다채로운"
,"스포츠"
,"폭력"
,"픽셀 그래픽"
,"탐험"
,"귀여운"
,"레이싱"
,"1인칭"
,"누드"
,"선정적인 내용"
,"애니메이션"
,"유머"
,"고어"
,"공상과학"
,"아케이드"
,"전투"
,"슈팅"
,"액션 어드벤처"
,"릴랙싱"
,"공포"
,"전체 이용가"
,"복고풍"
,"오픈 월드"
,"플랫폼"
,"여주인공"
,"3인칭"
,"협동"
,"생존"
,"양식화된"
,"컨트롤러"
,"PvP"
,"코미디"
,"선택의 중요성"
,"고난이도"
,"웅장한 사운드트랙"
,"현실적"
,"탑다운"
,"비주얼 노벨"
,"VR"
,"올드 스쿨"
,"1인칭 슈팅"
,"물리"
,"어두운"
,"캐릭터 커스터마이즈"
,"온라인 협동"
,"만화 같은"
,"미스터리"
,"PvE"
,"2D 플랫폼"
,"복수 결말"
,"선형"
,"심리적 공포"
,"샌드박스"
,"전술"
,"중세"
,"마법"
,"미니멀리스트"
,"우주"
,"미래적"
,"액션 RPG"
,"건설"
,"슛뎀업"
,"포인트 앤드 클릭"
,"디자인 및 일러스트레이션"
,"손으로 그린"
,"경영"
,"크래프팅"
,"로컬 멀티플레이어"
,"유틸리티"
,"횡스크롤"
,"만화"
,"절차적 생성"
,"1980년대"
,"드라마"
,"교육"
,"성인"
,"로그라이크"
,"자원관리"
,"퍼즐 플랫폼"
,"생존 공포"
,"논리"
,"다크 판타지"
,"3D 플랫폼"
,"자신이 선택하는 모험"
,"턴제 전투"
,"로그라이트"
,"전쟁"
,"로맨스"
,"핵 앤 슬래시"
,"턴제 전략"
,"좀비"
,"테이블탑"
,"포스트아포칼립스"
,"리플레이 가치"
,"턴제 전술"
,"턴제"
,"감정적인"
,"쌍방향 소설"
,"로컬 협동"
,"기지 건설"
,"JRPG"
,"연애 시뮬레이션"
,"헨타이"
,"자연"
,"히든 오브젝트"
,"초현실적"
,"역사"
,"몰입형 시뮬레이션"
,"파티 기반 RPG"
,"잠입"
,"1990년대"
,"내레이션"
,"던전 크롤러"
,"걷기 시뮬레이션"
,"탄막 슈팅"
,"스코어 어택"
,"밈"
,"군사"
,"액션 로그라이크"
,"웹 퍼블리싱"
,"3인칭 슈팅"
,"시네마틱"
,"탑다운 슈팅"
,"외계인"
,"로봇"
,"2.5D"
,"텍스트 기반"
,"대화"
,"사이버펑크"
,"팀 기반"
,"등각"
,"LGBTQ+"
,"블랙 유머"
,"빠른 진행"
,"후방주의"
,"실시간 전략"
,"수사"
,"비선형"
,"단편"
,"클래식"
,"인벤토리 관리"
,"튜토리얼"
,"카드 게임"
,"애니메이션과 모델링"
,"인공 지능"
,"추상적"
,"악령"
,"경제"
,"깊은 세계관"
,"생활 시뮬레이션"
,"운전"
,"소프트웨어"
,"퍼마 데스"
,"클리커"
,"심리적"
,"스릴러"
,"전략 RPG"
,"실시간 전술"
,"수사관"
,"영화"
,"아레나 슈팅"
,"보드게임"
,"4명 로컬 플레이"
,"현대"
,"초자연적"
,"음악"
,"RPG 제작"
,"비행"
,"반이상향"
,"정밀 플랫폼"
,"사이키델릭"
,"시간 관리"
,"아름다운"
,"약탈"
,"사운드트랙"
,"타워 디펜스"
,"실험적"
,"도시 건설"
,"전술 RPG"
,"격투"
,"모드 가능"
,"파괴"
,"비뎀업"
,"메트로배니아"
,"전쟁 게임"
,"소울라이크"
,"대체 역사"
,"오디오 프로덕션"
,"만화책"
,"레벨 에디터"
,"동영상 프로덕션"
,"경쟁"
,"신화"
,"러너"
,"범죄"
,"2D 격투"
,"파쿠르"
,"그리드 기반 움직임"
,"게임 개발"
,"MMORPG"
,"블랙 코미디"
,"컬렉터톤"
,"CRPG"
,"철학적"
,"클래스 기반"
,"제2차 세계 대전"
,"아이들러"
,"과학"
,"총 커스터마이즈"
,"자동차 시뮬레이션"
,"트윈 스틱 슈팅"
,"협동 캠페인"
,"덱빌딩"
,"리듬"
,"우주 시뮬레이션"
,"칼 싸움"
,"대전략"
,"고양이"
,"차량 전투"
,"카드 배틀"
,"캐릭터 액션 게임"
,"배틀 로얄"
,"러브크래프트"
,"용"
,"소프트웨어 교육"
,"6DOF"
,"유혈"
,"3D 격투"
,"e스포츠"
,"3D 비전"
,"아메리카"
,"누아르"
,"매치 3"
,"음모"
,"분할 화면"
,"패러디"
,"자본주의"
,"중독성"
,"풍자"
,"블렛타임"
,"자동화"
,"개척 시뮬레이션"
,"오픈 월드 생존 제작"
,"거래"
,"일루미나티"
,"미스터리 던전"
,"퀵타임 이벤트"
,"시간 조종"
,"복셀"
,"히어로 슈팅"
,"정치적"
,"농장 시뮬레이션"
,"스팀펑크"
,"다이내믹 내레이션"
,"고딕"
,"지하"
,"농업"
,"생명체 수집가"
,"낱말 게임"
,"사냥"
,"매크"
,"시간 여행"
,"무술"
,"마이닝"
,"약탈 슈팅"
,"마우스만 사용"
,"전투 레이싱"
,"사진 편집"
,"스펙터클 파이터"
,"MOBA"
,"오토메"
,"개"
,"탱크"
,"실시간"
,"신 게임"
,"컬트 클래식"
,"해적"
,"닌자"
,"서사"
,"해킹"
,"에피소드"
,"리메이크"
,"요리"
,"정치"
,"솔리테어"
,"비동기 멀티플레이어"
,"육각형 그리드"
,"FMV"
,"트레이딩 카드 게임"
,"냉전"
,"낚시"
,"뱀파이어"
,"슈퍼 히어로"
,"암살"
,"수중"
,"4X"
,"내러티브"
,"신념"
,"몰입형"
,"프로그래밍"
,"공룡"
,"오토 배틀러"
,"소코반"
,"정치 시뮬레이션"
,"강도"
,"웨스턴"
,"해군"
,"액션 RTS"
,"기차"
,"일시 정지 가능한 실시간"
,"파티"
,"파티 게임"
,"미니게임"
,"활쏘기"
,"외교"
,"교통 수단"
,"외국"
,"눈"
,"킥스타터"
,"해상 전투"
,"던전 앤 드래곤"
,"모드"
,"항해"
,"타이핑"
,"속편"
,"트랜스휴머니즘"
,"도박"
,"터치 친화적"
,"게임메이커"
,"체험"
,"악당 주인공"
,"음악 기반 절차적 생성"
,"화성"
,"저격수"
,"시간 공격"
,"레일 슈팅"
,"추억 소환"
,"360 동영상"
,"축구"
,"오프로드"
,"방 탈출"
,"제1차 세계 대전"
,"늑대 인간"
,"미식축구"
,"말"
,"게임즈 워크숍"
,"상식 퀴즈"
,"다큐멘터리"
,"정통 로그라이크"
,"로그라이크 덱빌딩"
,"파밍"
,"게이밍"
,"건전함"
,"복싱"
,"아늑함"
,"말을 안 하는 주인공"
,"체스"
,"제트"
,"초고난도"
,"우주선"
,"아웃브레이크 시뮬레이션"
,"크라우드펀딩"
,"레고"
,"골프"
,"의학 시뮬레이션"
,"맞춤법"
,"오토바이"
,"로마"
,"비대칭 VR"
,"전자 음악"
,"분위기"
,"잠수함"
,"로그바니아"
,"TrackIR"
,"핀볼"
,"바이크"
,"농구"
,"소셜 디덕션"
,"워해머 40K"
,"소설 기반"
,"미니 골프"
,"바이킹"
,"스케이트보딩"
,"레슬링"
,"인스트루멘탈 음악"
,"의도적으로 불편한 컨트롤"
,"당구"
,"야구"
,"테니스"
,"스케이팅"
,"모터크로스"
,"사이클링"
,"레밍"
,"벤치마크"
,"볼링"
,"하드웨어"
,"하키"
,"락 음악"
,"보스 러시"
,"깜놀"
,"Steam Machine"
,"8비트 음악"
,"일렉트로닉"
,"ATV"
,"훌륭한 각본"
,"BMX"
,"스노보딩"
,"스키"
,"보이스 컨트롤"
,"장편 영화"
,"직업 시뮬레이션"
,"무쌍"
,"럭비"
,"리부트"
,"마작"
,"크리켓"
,"배구"
,"스누커"
,"타일 매치"
,"코딩"
,"사업장 관리"
,"취미 시뮬레이션"
]

# %%
b=[]
for i in tag_list:
    a=[]
    for j in tag_tag:
        if(j in i[0]):
            a.append(j)
    b.append(a)

# %%
b
# Out:
# [['액션', 'RPG', 'MMO', '전투', '협동', 'MMORPG'],
#  ['액션', '멀티플레이어', '1인칭', '슈팅', '1인칭 슈팅', '군사'],
#  ['RPG', '전략', '오픈 월드', '중세', '전쟁'],
#  ['액션', 'RPG', '여주인공', '액션 RPG', 'JRPG'],
#  ['액션', 'RPG', '오픈 월드', '협동', '온라인 협동', '액션 RPG', '슈퍼 히어로'],
#  ['액션', '2D', '픽셀 그래픽', '슈팅', '로그라이크', '로그라이트', '탄막 슈팅', '액션 로그라이크'],
#  ['액션', '어드벤처', '공상과학', '공포', '여주인공', '생존', '생존 공포', '과학'],
#  ['액션', 'RPG', '액션 RPG', '핵 앤 슬래시', '약탈'],
#  ['액션', '어드벤처', '싱글 플레이어', '풍부한 스토리', '액션 어드벤처', '3인칭'],
#  ['액션', 'MMO', '슈팅', '생존', '배틀 로얄'],
#  ['캐주얼', '슈팅', '탑다운', '슛뎀업', '로그라이트', '탄막 슈팅'],
#  ['액션',
#   '슈팅',
#   '탑다운',
#   '로그라이크',
#   '로그라이트',
#   '탄막 슈팅',
#   '액션 로그라이크',
#   '탑다운 슈팅',
#   '아레나 슈팅']]

# %%
'액션'in '전투RPG액션협동MMORPG'
# Out:
# True

# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains

import time

driver = webdriver.Chrome("./chromedriver")

driver.get('https://store.steampowered.com/search/?filter=topsellers')

time.sleep(3)

action = ActionChains(driver)


driver.find_element(By.CSS_SELECTOR,"#language_pulldown").click()
driver.find_element(By.CSS_SELECTOR,"#language_dropdown > div > a:nth-child(4)").click()
# Out:
# C:\Users\dahun\AppData\Local\Temp\ipykernel_21708\1404074907.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("./chromedriver")

# %%
for i in range(1,51):
    action.move_to_element(driver.find_element(By.CSS_SELECTOR,"#search_resultsRows > a:nth-child({})".format(i))).perform()
    time.sleep(1)

# %%
Games1=driver.find_elements(By.CLASS_NAME,"hover_tag_row")

# %%
Games1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="79b4f0a9-17c6-47bf-9304-1ffb209895ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="efe0ef53-1637-4137-bf29-b78592443f73")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="14f39d89-ad8e-4a8d-a92a-697aec2b6ee4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="ac379913-b359-4b11-b382-1715ecbd838b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="a0719a60-e89d-4289-b312-5a0fc878b59d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="461ac92d-7569-470f-8caa-bf88d5493931")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="2c0dbe80-12b6-4229-b296-dc40a6b4f685")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="6c699cbf-b274-43a4-96bf-7bd369df9329")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="a72192f4-8dc2-44c4-86dc-84fcf5674f94")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="08f830e2-8977-406c-af7b-a33b1e8aa294")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="ecb2c194-6590-4e5f-9e8f-296f264fec35")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="981e9b1b-0b8e-4644-84fa-1b96290e1429")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="59966aee-db44-4663-8acb-c4eeb4546768")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="067ecfac-1840-43bf-8592-26b8f92aa465")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="3ba79181-ebc3-41c7-aa13-942e78009592")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="36f89c53-cf74-4db8-ade5-5a5f15123ad2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="a03612f3-ec09-4fa1-8b48-b69885cba1b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="c159aa62-22fc-4a3e-b104-935fd989db8e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="ba6d3423-3c0e-436b-90d4-685e9c687e1b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="31e52b18-09a9-4509-915f-13b3e423f301")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="94db7546-01fa-4d8b-b1a7-36ecaa22ca76")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="0821eeea-fe1d-4ccd-877d-a28f857d02f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="f55fceeb-80ef-4603-bce6-c99b6b3232af")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="27cdd148-b12a-44d2-b4eb-b94daa3b4575")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="c5dc332a-f4f3-4f92-8519-7d80beb8f6d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="349937e8-6870-4867-ae6e-e7db79772394")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="dede75f4-0777-474a-94cd-50f825e80e1d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="06cff32c-b234-4663-bd63-a0f019c2c6d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="297b8587-d5d6-4f8a-a12c-645544005443")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="c9d35148-ac81-4fde-80d9-0a6937909c95")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="5fff7cb6-c757-4f5f-a38c-1a6e4789adf9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="74728e8c-7fbb-4481-ba88-4561280ac7b5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="565c6582-012c-4c5d-b891-03dead46c8f0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="3d90063f-ad04-4262-80de-a3b030226f46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="c88673e0-6db2-4b04-9c6a-539595a24b59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="bd44c141-6f79-4697-b448-8e370ea21732")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="d3acf16b-13c9-417b-882a-3d2380b58450")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="c8723059-9d26-471a-9fd4-fcbd2aa4bf83")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="bf5bcaa6-eb9a-4eac-9f3c-17c5cb780e7a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="b2f96057-e4ae-451f-8017-dfcf82bd6b0f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="d7bbbddc-3d40-4263-8f2b-16fcac950d05")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="f53ccf79-5b7a-469b-b979-7ced174f9fa3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="02b6de20-7a6a-4886-9481-58f0ec58b99c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="03e37feb-3e0b-4259-82a5-2557423871af")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="c8d170ee-ac9f-4bf2-8ff6-127348677881")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="891dd968-ee39-4b10-a30e-98fa925d7a69")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="b0a72fdb-dfcb-4b74-9457-fbe20036e7b7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="ae7ffc00-757b-4315-84bd-93afc8eb0c82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="1d447c77-7470-41f0-8e98-989f71798f8e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cd4d365c7bb4d13fb4379df79bb04865", element="d8de5961-bbeb-46e1-913f-70581aabd618")>]

# %%
Games3=list(map(lambda x : x.get_attribute('textContent').replace('\n'," ").lstrip().rstrip(),Games1))

# %%
Games3
# Out:
# ['1인칭 슈팅액션슈팅멀티플레이어군사1인칭싱글 플레이어현대전쟁전술풍부한 스토리현실적폭력협동분위기 있는성인온라인 협동고어3인칭 슈팅3인칭',
#  '생존슈팅멀티플레이어배틀 로얄1인칭 슈팅PvP3인칭 슈팅액션온라인 협동전술협동1인칭전략앞서 해보기경쟁3인칭팀 기반고난이도시뮬레이션잠입',
#  '액션 어드벤처픽셀 그래픽탐험경영수중RPG2.5D싱글 플레이어풍부한 스토리전투어드벤처앞서 해보기낚시',
#  '시뮬레이션스포츠실시간 전술경영e스포츠2D축구3D멀티플레이어미식축구텍스트 기반전략싱글 플레이어판타지',
#  '앞서 해보기생존오픈 월드뱀파이어크래프팅기지 건설PvP멀티플레이어PvE건설온라인 협동핵 앤 슬래시샌드박스탐험액션 어드벤처액션MMO어드벤처싱글 플레이어다크 판타지',
#  'MMOPvP스포츠축구MOBA실시간 전략e스포츠캐릭터 커스터마이즈RPG3인칭만화책3D액션캐주얼애니메이션만화 같은양식화된만화협동온라인 협동',
#  '대전략경제전략역사시뮬레이션경영대체 역사외교정치적싱글 플레이어일시 정지 가능한 실시간정치멀티플레이어모드 가능샌드박스정치 시뮬레이션자원관리군사리플레이 가치자본주의',
#  '무료 플레이멀티플레이어배틀 로얄슈팅1인칭1인칭 슈팅PvP액션히어로 슈팅팀 기반전술캐릭터 커스터마이즈생존공상과학약탈유머깊은 세계관협동사이버펑크시네마틱',
#  '액션PvPPvE액션 RPG캐주얼온라인 협동무료 플레이핵 앤 슬래시캐릭터 커스터마이즈풍부한 스토리2D 격투비뎀업컨트롤러멀티플레이어애니메이션2.5D판타지귀여운3D 격투MMO',
#  '스포츠축구몰입형 시뮬레이션경영PvP미식축구e스포츠컨트롤러3인칭팀 기반시뮬레이션현실적협동로컬 협동로컬 멀티플레이어멀티플레이어온라인 협동싱글 플레이어PvE애니메이션',
#  '앞서 해보기RPG액션 RPG핵 앤 슬래시약탈액션어드벤처전투액션 어드벤처던전 크롤러탑다운멀티플레이어싱글 플레이어드라마판타지풍부한 스토리캐릭터 커스터마이즈시간 여행무료 플레이협동',
#  '중세전략오픈 월드RPG전쟁멀티플레이어샌드박스싱글 플레이어액션시뮬레이션캐릭터 커스터마이즈모드 가능어드벤처말현실적3인칭1인칭역사웅장한 사운드트랙앞서 해보기',
#  '오픈 월드액션멀티플레이어범죄자동차 시뮬레이션3인칭1인칭슈팅성인어드벤처싱글 플레이어3인칭 슈팅레이싱협동분위기 있는샌드박스유머웅장한 사운드트랙코미디모드 가능',
#  '1인칭 슈팅멀티플레이어제1차 세계 대전전쟁슈팅싱글 플레이어액션1인칭분위기 있는PvP역사MMO오픈 월드파괴고어탱크물리폭력웅장한 사운드트랙성인',
#  '무료 플레이차량 전투전투VR제2차 세계 대전비행전쟁해상 전투군사탱크현대3인칭 슈팅시뮬레이션3인칭냉전현실적슈팅MMO역사액션',
#  '무료 플레이MOBA멀티플레이어전략e스포츠팀 기반경쟁액션온라인 협동PvP고난이도협동실시간 전략타워 디펜스RPG판타지캐릭터 커스터마이즈리플레이 가치액션 RPG시뮬레이션',
#  'JRPG풍부한 스토리애니메이션RPG파티 기반 RPG턴제 전투웅장한 사운드트랙턴제 전략싱글 플레이어감정적인다채로운복수 결말비주얼 노벨연애 시뮬레이션어드벤처선정적인 내용강도수사관사운드트랙폭력',
#  '협동1인칭게임즈 워크숍다크 판타지폭력핵 앤 슬래시고어온라인 협동액션액션 RPG판타지멀티플레이어PvE로그라이트분위기 있는1인칭 슈팅싱글 플레이어생존어드벤처인디',
#  '무료 플레이오픈 월드1인칭 슈팅약탈 슈팅MMORPGPvPPvE협동슈팅1인칭MMO공상과학약탈액션깊은 세계관멀티플레이어우주어드벤처경쟁분위기 있는',
#  '무료 플레이액션 RPG약탈 슈팅RPG액션3인칭 슈팅3인칭캐릭터 커스터마이즈MMO온라인 협동협동깊은 세계관공상과학PvE싱글 플레이어우주슈팅핵 앤 슬래시파쿠르닌자',
#  '개척 시뮬레이션기지 건설생존전략경영샌드박스건설시뮬레이션도시 건설싱글 플레이어모드 가능오픈 월드절차적 생성2D공상과학인디우주전술 RPG웨스턴만화 같은',
#  '전략카드 배틀PvP캐주얼카드 게임턴제 전술덱빌딩무료 플레이슈퍼 히어로만화책앞서 해보기멀티플레이어양식화된',
#  '미스터리협동온라인 협동비동기 멀티플레이어로컬 멀티플레이어인디로컬 협동멀티플레이어어드벤처퍼즐공포포인트 앤드 클릭방 탈출풍부한 스토리분위기 있는2D심리적 공포스릴러초현실적3D',
#  '카드 게임무료 플레이전략트레이딩 카드 게임PvP카드 배틀멀티플레이어시뮬레이션애니메이션턴제 전술전술e스포츠판타지싱글 플레이어용PvE생존 공포3D2D웅장한 사운드트랙',
#  '리듬액션캐주얼음악스포츠사운드트랙싱글 플레이어앞서 해보기고난이도애니메이션경쟁아케이드귀여운전자 음악현대다채로운음악 기반 절차적 생성만화공상과학PvP',
#  '액션캐주얼리듬아케이드2D애니메이션감정적인앞서 해보기드라마릴랙싱인디우주미래적싱글 플레이어선형음악',
#  '분위기 있는리듬싱글 플레이어1인칭 슈팅액션슈팅음악악령전투1인칭어드벤처스코어 어택여주인공3D양식화된시네마틱어두운다크 판타지내레이션판타지',
#  '앞서 해보기액션 로그라이크로그라이트아레나 슈팅탄막 슈팅탑다운 슈팅캐주얼2DRPG탑다운포스트아포칼립스액션절차적 생성손으로 그린유머외계인만화 같은컨트롤러전투퍼마 데스',
#  '생존오픈 월드 생존 제작멀티플레이어협동크래프팅오픈 월드건설기지 건설온라인 협동어드벤처샌드박스1인칭앞서 해보기싱글 플레이어수중시뮬레이션액션인디전략MMO',
#  '협동PvE1인칭 슈팅탐험약탈절차적 생성슈팅클래스 기반1인칭약탈 슈팅공상과학액션우주전투공포분위기 있는액션 로그라이크어두운생존오픈 월드',
#  '생존 공포공포1인칭싱글 플레이어액션선정적인 내용좀비고어분위기 있는풍부한 스토리폭력1인칭 슈팅어두운심리적 공포생존어드벤처오픈 월드멀티플레이어누드VR',
#  '1인칭 슈팅슈팅멀티플레이어경쟁액션팀 기반e스포츠전술1인칭PvP온라인 협동협동전략군사전쟁고난이도거래현실적빠른 진행모드 가능',
#  '전략기지 건설시뮬레이션도시 건설개척 시뮬레이션경영자원관리건설샌드박스생존실시간 전략오픈 월드경제중세싱글 플레이어모드 가능크래프팅리플레이 가치역사앞서 해보기',
#  '좀비생존 공포공포온라인 협동오픈 월드파쿠르1인칭생존오픈 월드 생존 제작액션1인칭 슈팅고어PvEPvP잠입포스트아포칼립스풍부한 스토리액션 RPG핵 앤 슬래시RPG',
#  '슈퍼 히어로액션오픈 월드싱글 플레이어어드벤처풍부한 스토리전투액션 어드벤처3인칭만화책파쿠르탐험아름다운캐주얼웅장한 사운드트랙잠입유머분위기 있는공상과학멀티플레이어',
#  '도시 건설생존전략자원관리포스트아포칼립스스팀펑크개척 시뮬레이션건설기지 건설시뮬레이션싱글 플레이어경영선택의 중요성분위기 있는경제어두운실시간 전략고난이도웅장한 사운드트랙일시 정지 가능한 실시간',
#  '농장 시뮬레이션생활 시뮬레이션픽셀 그래픽RPG멀티플레이어릴랙싱농업시뮬레이션크래프팅샌드박스인디건설싱글 플레이어캐주얼오픈 월드2D웅장한 사운드트랙귀여운연애 시뮬레이션낚시',
#  '인디전략시뮬레이션개척 시뮬레이션싱글 플레이어심리적 공포',
#  '공포생존 공포멀티플레이어온라인 협동협동생존고어유혈팀 기반잠입3인칭폭력1인칭심리적 공포액션분위기 있는전략코미디성인고난이도',
#  '로그라이트액션 로그라이크협동픽셀 그래픽RPG멀티플레이어던전 크롤러온라인 협동인디액션어드벤처2D절차적 생성탑다운로그라이크핵 앤 슬래시싱글 플레이어탄막 슈팅액션 RPG판타지',
#  '액션 로그라이크로그라이크인디리플레이 가치고난이도픽셀 그래픽던전 크롤러웅장한 사운드트랙싱글 플레이어어두운2D리메이크로컬 협동고어절차적 생성로그라이트분위기 있는액션협동공포',
#  '사이버펑크오픈 월드RPG누드싱글 플레이어공상과학미래적1인칭 슈팅1인칭풍부한 스토리성인분위기 있는탐험액션폭력웅장한 사운드트랙액션 RPG어드벤처캐릭터 커스터마이즈몰입형 시뮬레이션',
#  '전략MMO무료 플레이RPG액션시뮬레이션중세오픈 월드전쟁멀티플레이어고어폭력생존핵 앤 슬래시전쟁 게임실시간 전략협동싱글 플레이어MMORPG앞서 해보기',
#  '앞서 해보기배틀 로얄슈팅생존액션MMOPvP3인칭 슈팅멀티플레이어1인칭 슈팅3인칭1인칭총 커스터마이즈현실적캐주얼전쟁전쟁 게임RPG3D액션 RPG',
#  '소울라이크다크 판타지RPG고난이도오픈 월드액션 RPG3인칭판타지멀티플레이어싱글 플레이어온라인 협동액션PvP협동폭력분위기 있는웅장한 사운드트랙3D캐릭터 커스터마이즈전체 이용가',
#  'JRPG여주인공RPG애니메이션어드벤처판타지싱글 플레이어선정적인 내용성인크래프팅오픈 월드귀여운풍부한 스토리액션시뮬레이션누드캐주얼턴제헨타이',
#  '오픈 월드 생존 제작생존오픈 월드멀티플레이어공룡크래프팅건설어드벤처기지 건설협동액션1인칭샌드박스MMO싱글 플레이어앞서 해보기RPG용공상과학인디',
#  '생존멀티플레이어기지 건설협동오픈 월드 생존 제작크래프팅어드벤처오픈 월드공포액션온라인 협동탐험샌드박스1인칭싱글 플레이어앞서 해보기RPG3인칭유머귀여운',
#  '어드벤처약탈슈팅1인칭 슈팅멀티플레이어판타지RPG액션약탈 슈팅온라인 협동코미디양식화된내레이션싱글 플레이어캐릭터 커스터마이즈협동클래스 기반PvE로컬 협동3D',
#  '액션캐주얼스포츠']

# %%
b=[]
for i in Games3:
    a=[]
    for j in tag_tag:
        if(j in i):
            a.append(j)
    b.append(a)

# %%
b
# Out:
# [['액션',
#   '싱글 플레이어',
#   '분위기 있는',
#   '풍부한 스토리',
#   '멀티플레이어',
#   '폭력',
#   '1인칭',
#   '고어',
#   '슈팅',
#   '3인칭',
#   '협동',
#   '현실적',
#   '1인칭 슈팅',
#   '온라인 협동',
#   '전술',
#   '성인',
#   '전쟁',
#   '군사',
#   '3인칭 슈팅',
#   '현대',
#   '분위기'],
#  ['액션',
#   '시뮬레이션',
#   '전략',
#   '앞서 해보기',
#   '멀티플레이어',
#   '1인칭',
#   '슈팅',
#   '3인칭',
#   '협동',
#   '생존',
#   'PvP',
#   '고난이도',
#   '1인칭 슈팅',
#   '온라인 협동',
#   '전술',
#   '잠입',
#   '3인칭 슈팅',
#   '팀 기반',
#   '경쟁',
#   '배틀 로얄'],
#  ['액션',
#   '어드벤처',
#   'RPG',
#   '싱글 플레이어',
#   '앞서 해보기',
#   '풍부한 스토리',
#   '픽셀 그래픽',
#   '탐험',
#   '전투',
#   '액션 어드벤처',
#   '경영',
#   '2.5D',
#   '낚시',
#   '수중'],
#  ['시뮬레이션',
#   '전략',
#   '싱글 플레이어',
#   '2D',
#   '3D',
#   '판타지',
#   '멀티플레이어',
#   '스포츠',
#   '전술',
#   '경영',
#   '텍스트 기반',
#   '실시간 전술',
#   'e스포츠',
#   '실시간',
#   '축구',
#   '미식축구'],
#  ['액션',
#   '어드벤처',
#   '싱글 플레이어',
#   '앞서 해보기',
#   '판타지',
#   '멀티플레이어',
#   'MMO',
#   '탐험',
#   '액션 어드벤처',
#   '오픈 월드',
#   '협동',
#   '생존',
#   'PvP',
#   '온라인 협동',
#   'PvE',
#   '샌드박스',
#   '건설',
#   '크래프팅',
#   '다크 판타지',
#   '핵 앤 슬래시',
#   '기지 건설',
#   '뱀파이어'],
#  ['액션',
#   '캐주얼',
#   'RPG',
#   '전략',
#   '3D',
#   'MMO',
#   '스포츠',
#   '애니메이션',
#   '3인칭',
#   '협동',
#   '양식화된',
#   'PvP',
#   '캐릭터 커스터마이즈',
#   '온라인 협동',
#   '만화 같은',
#   '만화',
#   '실시간 전략',
#   '만화책',
#   'e스포츠',
#   'MOBA',
#   '실시간',
#   '축구'],
#  ['시뮬레이션',
#   '전략',
#   '싱글 플레이어',
#   '멀티플레이어',
#   '샌드박스',
#   '경영',
#   '자원관리',
#   '리플레이 가치',
#   '역사',
#   '군사',
#   '경제',
#   '모드 가능',
#   '대체 역사',
#   '대전략',
#   '자본주의',
#   '정치적',
#   '실시간',
#   '정치',
#   '정치 시뮬레이션',
#   '일시 정지 가능한 실시간',
#   '외교',
#   '모드'],
#  ['액션',
#   '무료 플레이',
#   '멀티플레이어',
#   '1인칭',
#   '유머',
#   '공상과학',
#   '슈팅',
#   '협동',
#   '생존',
#   'PvP',
#   '1인칭 슈팅',
#   '캐릭터 커스터마이즈',
#   '전술',
#   '시네마틱',
#   '사이버펑크',
#   '팀 기반',
#   '깊은 세계관',
#   '약탈',
#   '과학',
#   '배틀 로얄',
#   '히어로 슈팅'],
#  ['액션',
#   '캐주얼',
#   'RPG',
#   '무료 플레이',
#   '2D',
#   '3D',
#   '풍부한 스토리',
#   '판타지',
#   '멀티플레이어',
#   'MMO',
#   '귀여운',
#   '애니메이션',
#   '협동',
#   '컨트롤러',
#   'PvP',
#   '캐릭터 커스터마이즈',
#   '온라인 협동',
#   'PvE',
#   '액션 RPG',
#   '핵 앤 슬래시',
#   '2.5D',
#   '격투',
#   '비뎀업',
#   '2D 격투',
#   '3D 격투'],
#  ['시뮬레이션',
#   '싱글 플레이어',
#   '멀티플레이어',
#   '스포츠',
#   '애니메이션',
#   '3인칭',
#   '협동',
#   '컨트롤러',
#   'PvP',
#   '현실적',
#   '온라인 협동',
#   'PvE',
#   '경영',
#   '로컬 멀티플레이어',
#   '로컬 협동',
#   '몰입형 시뮬레이션',
#   '팀 기반',
#   'e스포츠',
#   '몰입형',
#   '축구',
#   '미식축구'],
#  ['액션',
#   '어드벤처',
#   'RPG',
#   '싱글 플레이어',
#   '앞서 해보기',
#   '무료 플레이',
#   '풍부한 스토리',
#   '판타지',
#   '멀티플레이어',
#   '전투',
#   '액션 어드벤처',
#   '협동',
#   '탑다운',
#   '캐릭터 커스터마이즈',
#   '액션 RPG',
#   '드라마',
#   '핵 앤 슬래시',
#   '던전 크롤러',
#   '약탈',
#   '시간 여행'],
#  ['액션',
#   '어드벤처',
#   '시뮬레이션',
#   'RPG',
#   '전략',
#   '싱글 플레이어',
#   '앞서 해보기',
#   '멀티플레이어',
#   '1인칭',
#   '오픈 월드',
#   '3인칭',
#   '웅장한 사운드트랙',
#   '현실적',
#   '캐릭터 커스터마이즈',
#   '샌드박스',
#   '중세',
#   '전쟁',
#   '역사',
#   '사운드트랙',
#   '모드 가능',
#   '모드',
#   '말'],
#  ['액션',
#   '어드벤처',
#   '시뮬레이션',
#   '싱글 플레이어',
#   '분위기 있는',
#   '멀티플레이어',
#   '레이싱',
#   '1인칭',
#   '유머',
#   '슈팅',
#   '오픈 월드',
#   '3인칭',
#   '협동',
#   '코미디',
#   '웅장한 사운드트랙',
#   '샌드박스',
#   '성인',
#   '3인칭 슈팅',
#   '사운드트랙',
#   '모드 가능',
#   '범죄',
#   '자동차 시뮬레이션',
#   '모드',
#   '분위기'],
#  ['액션',
#   '싱글 플레이어',
#   '분위기 있는',
#   '멀티플레이어',
#   'MMO',
#   '폭력',
#   '1인칭',
#   '고어',
#   '슈팅',
#   '오픈 월드',
#   'PvP',
#   '웅장한 사운드트랙',
#   '1인칭 슈팅',
#   '물리',
#   '성인',
#   '전쟁',
#   '역사',
#   '사운드트랙',
#   '파괴',
#   '탱크',
#   '제1차 세계 대전',
#   '분위기'],
#  ['액션',
#   '시뮬레이션',
#   '무료 플레이',
#   'MMO',
#   '전투',
#   '슈팅',
#   '3인칭',
#   '현실적',
#   'VR',
#   '전쟁',
#   '역사',
#   '군사',
#   '3인칭 슈팅',
#   '현대',
#   '비행',
#   '제2차 세계 대전',
#   '차량 전투',
#   '탱크',
#   '냉전',
#   '해상 전투'],
#  ['액션',
#   '시뮬레이션',
#   'RPG',
#   '전략',
#   '무료 플레이',
#   '판타지',
#   '멀티플레이어',
#   '스포츠',
#   '협동',
#   'PvP',
#   '고난이도',
#   '캐릭터 커스터마이즈',
#   '온라인 협동',
#   '액션 RPG',
#   '리플레이 가치',
#   '팀 기반',
#   '실시간 전략',
#   '타워 디펜스',
#   '경쟁',
#   'e스포츠',
#   'MOBA',
#   '실시간'],
#  ['어드벤처',
#   '시뮬레이션',
#   'RPG',
#   '전략',
#   '싱글 플레이어',
#   '풍부한 스토리',
#   '다채로운',
#   '폭력',
#   '선정적인 내용',
#   '애니메이션',
#   '전투',
#   '웅장한 사운드트랙',
#   '비주얼 노벨',
#   '복수 결말',
#   '턴제 전투',
#   '턴제 전략',
#   '턴제',
#   '감정적인',
#   'JRPG',
#   '연애 시뮬레이션',
#   '파티 기반 RPG',
#   '수사',
#   '수사관',
#   '사운드트랙',
#   '용',
#   '강도',
#   '파티',
#   '말'],
#  ['인디',
#   '액션',
#   '어드벤처',
#   'RPG',
#   '싱글 플레이어',
#   '분위기 있는',
#   '판타지',
#   '멀티플레이어',
#   '폭력',
#   '1인칭',
#   '고어',
#   '슈팅',
#   '협동',
#   '생존',
#   '1인칭 슈팅',
#   '온라인 협동',
#   'PvE',
#   '액션 RPG',
#   '다크 판타지',
#   '로그라이트',
#   '핵 앤 슬래시',
#   '게임즈 워크숍',
#   '분위기'],
#  ['액션',
#   '어드벤처',
#   'RPG',
#   '무료 플레이',
#   '분위기 있는',
#   '멀티플레이어',
#   'MMO',
#   '1인칭',
#   '공상과학',
#   '슈팅',
#   '오픈 월드',
#   '협동',
#   'PvP',
#   '1인칭 슈팅',
#   'PvE',
#   '우주',
#   '깊은 세계관',
#   '약탈',
#   '경쟁',
#   'MMORPG',
#   '과학',
#   '약탈 슈팅',
#   '분위기'],
#  ['액션',
#   'RPG',
#   '싱글 플레이어',
#   '무료 플레이',
#   'MMO',
#   '공상과학',
#   '슈팅',
#   '3인칭',
#   '협동',
#   '캐릭터 커스터마이즈',
#   '온라인 협동',
#   'PvE',
#   '우주',
#   '액션 RPG',
#   '핵 앤 슬래시',
#   '3인칭 슈팅',
#   '깊은 세계관',
#   '약탈',
#   '파쿠르',
#   '과학',
#   '약탈 슈팅',
#   '닌자'],
#  ['인디',
#   '시뮬레이션',
#   'RPG',
#   '전략',
#   '싱글 플레이어',
#   '2D',
#   '공상과학',
#   '오픈 월드',
#   '생존',
#   '만화 같은',
#   '샌드박스',
#   '전술',
#   '우주',
#   '건설',
#   '경영',
#   '만화',
#   '절차적 생성',
#   '기지 건설',
#   '도시 건설',
#   '전술 RPG',
#   '모드 가능',
#   '과학',
#   '개척 시뮬레이션',
#   '개',
#   '웨스턴',
#   '모드'],
#  ['캐주얼',
#   '전략',
#   '앞서 해보기',
#   '무료 플레이',
#   '멀티플레이어',
#   '양식화된',
#   'PvP',
#   '전술',
#   '만화',
#   '턴제 전술',
#   '턴제',
#   '카드 게임',
#   '만화책',
#   '덱빌딩',
#   '카드 배틀',
#   '슈퍼 히어로'],
#  ['인디',
#   '어드벤처',
#   '2D',
#   '분위기 있는',
#   '3D',
#   '풍부한 스토리',
#   '멀티플레이어',
#   '퍼즐',
#   '공포',
#   '협동',
#   '현실적',
#   '온라인 협동',
#   '미스터리',
#   '심리적 공포',
#   '포인트 앤드 클릭',
#   '로컬 멀티플레이어',
#   '로컬 협동',
#   '초현실적',
#   '심리적',
#   '스릴러',
#   '비동기 멀티플레이어',
#   '방 탈출',
#   '분위기'],
#  ['시뮬레이션',
#   '전략',
#   '싱글 플레이어',
#   '무료 플레이',
#   '2D',
#   '3D',
#   '판타지',
#   '멀티플레이어',
#   '스포츠',
#   '애니메이션',
#   '공포',
#   '생존',
#   'PvP',
#   '웅장한 사운드트랙',
#   'PvE',
#   '전술',
#   '생존 공포',
#   '턴제 전술',
#   '턴제',
#   '카드 게임',
#   '사운드트랙',
#   '카드 배틀',
#   '용',
#   'e스포츠',
#   '트레이딩 카드 게임'],
#  ['액션',
#   '캐주얼',
#   '싱글 플레이어',
#   '앞서 해보기',
#   '다채로운',
#   '스포츠',
#   '귀여운',
#   '애니메이션',
#   '공상과학',
#   '아케이드',
#   'PvP',
#   '고난이도',
#   '만화',
#   '절차적 생성',
#   '운전',
#   '현대',
#   '음악',
#   '사운드트랙',
#   '경쟁',
#   '과학',
#   '리듬',
#   '음악 기반 절차적 생성',
#   '전자 음악'],
#  ['인디',
#   '액션',
#   '캐주얼',
#   '싱글 플레이어',
#   '앞서 해보기',
#   '2D',
#   '애니메이션',
#   '아케이드',
#   '릴랙싱',
#   '선형',
#   '우주',
#   '미래적',
#   '드라마',
#   '감정적인',
#   '음악',
#   '리듬'],
#  ['액션',
#   '어드벤처',
#   '싱글 플레이어',
#   '분위기 있는',
#   '3D',
#   '판타지',
#   '1인칭',
#   '전투',
#   '슈팅',
#   '여주인공',
#   '양식화된',
#   '1인칭 슈팅',
#   '어두운',
#   '다크 판타지',
#   '내레이션',
#   '스코어 어택',
#   '시네마틱',
#   '악령',
#   '음악',
#   '리듬',
#   '분위기'],
#  ['액션',
#   '캐주얼',
#   'RPG',
#   '앞서 해보기',
#   '2D',
#   '유머',
#   '전투',
#   '슈팅',
#   '컨트롤러',
#   '탑다운',
#   '만화 같은',
#   '손으로 그린',
#   '만화',
#   '절차적 생성',
#   '로그라이크',
#   '로그라이트',
#   '포스트아포칼립스',
#   '탄막 슈팅',
#   '액션 로그라이크',
#   '탑다운 슈팅',
#   '외계인',
#   '퍼마 데스',
#   '아레나 슈팅'],
#  ['인디',
#   '액션',
#   '어드벤처',
#   '시뮬레이션',
#   '전략',
#   '싱글 플레이어',
#   '앞서 해보기',
#   '멀티플레이어',
#   'MMO',
#   '1인칭',
#   '오픈 월드',
#   '협동',
#   '생존',
#   '온라인 협동',
#   '샌드박스',
#   '건설',
#   '크래프팅',
#   '기지 건설',
#   '오픈 월드 생존 제작',
#   '수중'],
#  ['액션',
#   '분위기 있는',
#   '탐험',
#   '1인칭',
#   '공상과학',
#   '전투',
#   '슈팅',
#   '공포',
#   '오픈 월드',
#   '협동',
#   '생존',
#   '1인칭 슈팅',
#   '어두운',
#   'PvE',
#   '우주',
#   '절차적 생성',
#   '로그라이크',
#   '액션 로그라이크',
#   '약탈',
#   '클래스 기반',
#   '과학',
#   '약탈 슈팅',
#   '분위기'],
#  ['액션',
#   '어드벤처',
#   '싱글 플레이어',
#   '분위기 있는',
#   '풍부한 스토리',
#   '멀티플레이어',
#   '폭력',
#   '1인칭',
#   '누드',
#   '선정적인 내용',
#   '고어',
#   '슈팅',
#   '공포',
#   '오픈 월드',
#   '생존',
#   'VR',
#   '1인칭 슈팅',
#   '어두운',
#   '심리적 공포',
#   '생존 공포',
#   '좀비',
#   '심리적',
#   '용',
#   '분위기'],
#  ['액션',
#   '전략',
#   '멀티플레이어',
#   '스포츠',
#   '1인칭',
#   '슈팅',
#   '협동',
#   'PvP',
#   '고난이도',
#   '현실적',
#   '1인칭 슈팅',
#   '온라인 협동',
#   '전술',
#   '전쟁',
#   '군사',
#   '팀 기반',
#   '빠른 진행',
#   '모드 가능',
#   '경쟁',
#   'e스포츠',
#   '거래',
#   '모드'],
#  ['시뮬레이션',
#   '전략',
#   '싱글 플레이어',
#   '앞서 해보기',
#   '오픈 월드',
#   '생존',
#   '샌드박스',
#   '중세',
#   '건설',
#   '경영',
#   '크래프팅',
#   '자원관리',
#   '리플레이 가치',
#   '기지 건설',
#   '역사',
#   '실시간 전략',
#   '경제',
#   '도시 건설',
#   '모드 가능',
#   '개척 시뮬레이션',
#   '개',
#   '실시간',
#   '모드'],
#  ['액션',
#   'RPG',
#   '풍부한 스토리',
#   '1인칭',
#   '고어',
#   '슈팅',
#   '공포',
#   '오픈 월드',
#   '협동',
#   '생존',
#   'PvP',
#   '1인칭 슈팅',
#   '온라인 협동',
#   'PvE',
#   '액션 RPG',
#   '생존 공포',
#   '핵 앤 슬래시',
#   '좀비',
#   '포스트아포칼립스',
#   '잠입',
#   '파쿠르',
#   '오픈 월드 생존 제작'],
#  ['액션',
#   '어드벤처',
#   '캐주얼',
#   '싱글 플레이어',
#   '분위기 있는',
#   '풍부한 스토리',
#   '멀티플레이어',
#   '탐험',
#   '유머',
#   '공상과학',
#   '전투',
#   '액션 어드벤처',
#   '오픈 월드',
#   '3인칭',
#   '웅장한 사운드트랙',
#   '만화',
#   '잠입',
#   '아름다운',
#   '사운드트랙',
#   '만화책',
#   '파쿠르',
#   '과학',
#   '슈퍼 히어로',
#   '분위기'],
#  ['시뮬레이션',
#   '전략',
#   '싱글 플레이어',
#   '분위기 있는',
#   '생존',
#   '선택의 중요성',
#   '고난이도',
#   '웅장한 사운드트랙',
#   '어두운',
#   '건설',
#   '경영',
#   '자원관리',
#   '포스트아포칼립스',
#   '기지 건설',
#   '실시간 전략',
#   '경제',
#   '사운드트랙',
#   '도시 건설',
#   '개척 시뮬레이션',
#   '스팀펑크',
#   '개',
#   '실시간',
#   '일시 정지 가능한 실시간',
#   '분위기'],
#  ['인디',
#   '캐주얼',
#   '시뮬레이션',
#   'RPG',
#   '싱글 플레이어',
#   '2D',
#   '멀티플레이어',
#   '픽셀 그래픽',
#   '귀여운',
#   '릴랙싱',
#   '오픈 월드',
#   '웅장한 사운드트랙',
#   '샌드박스',
#   '건설',
#   '크래프팅',
#   '연애 시뮬레이션',
#   '생활 시뮬레이션',
#   '사운드트랙',
#   '농장 시뮬레이션',
#   '농업',
#   '낚시'],
#  ['인디', '시뮬레이션', '전략', '싱글 플레이어', '공포', '심리적 공포', '심리적', '개척 시뮬레이션', '개'],
#  ['액션',
#   '전략',
#   '분위기 있는',
#   '멀티플레이어',
#   '폭력',
#   '1인칭',
#   '고어',
#   '공포',
#   '3인칭',
#   '협동',
#   '생존',
#   '코미디',
#   '고난이도',
#   '온라인 협동',
#   '심리적 공포',
#   '성인',
#   '생존 공포',
#   '잠입',
#   '팀 기반',
#   '심리적',
#   '유혈',
#   '분위기'],
#  ['인디',
#   '액션',
#   '어드벤처',
#   'RPG',
#   '싱글 플레이어',
#   '2D',
#   '판타지',
#   '멀티플레이어',
#   '픽셀 그래픽',
#   '슈팅',
#   '협동',
#   '탑다운',
#   '온라인 협동',
#   '액션 RPG',
#   '절차적 생성',
#   '로그라이크',
#   '로그라이트',
#   '핵 앤 슬래시',
#   '던전 크롤러',
#   '탄막 슈팅',
#   '액션 로그라이크'],
#  ['인디',
#   '액션',
#   '싱글 플레이어',
#   '2D',
#   '분위기 있는',
#   '픽셀 그래픽',
#   '고어',
#   '공포',
#   '협동',
#   '고난이도',
#   '웅장한 사운드트랙',
#   '어두운',
#   '절차적 생성',
#   '로그라이크',
#   '로그라이트',
#   '리플레이 가치',
#   '로컬 협동',
#   '던전 크롤러',
#   '액션 로그라이크',
#   '사운드트랙',
#   '리메이크',
#   '분위기'],
#  ['액션',
#   '어드벤처',
#   '시뮬레이션',
#   'RPG',
#   '싱글 플레이어',
#   '분위기 있는',
#   '풍부한 스토리',
#   '폭력',
#   '탐험',
#   '1인칭',
#   '누드',
#   '공상과학',
#   '슈팅',
#   '오픈 월드',
#   '웅장한 사운드트랙',
#   '1인칭 슈팅',
#   '캐릭터 커스터마이즈',
#   '미래적',
#   '액션 RPG',
#   '성인',
#   '몰입형 시뮬레이션',
#   '사이버펑크',
#   '사운드트랙',
#   '과학',
#   '몰입형',
#   '분위기'],
#  ['액션',
#   '시뮬레이션',
#   'RPG',
#   '전략',
#   '싱글 플레이어',
#   '앞서 해보기',
#   '무료 플레이',
#   '멀티플레이어',
#   'MMO',
#   '폭력',
#   '고어',
#   '오픈 월드',
#   '협동',
#   '생존',
#   '중세',
#   '전쟁',
#   '핵 앤 슬래시',
#   '실시간 전략',
#   '전쟁 게임',
#   'MMORPG',
#   '실시간'],
#  ['액션',
#   '캐주얼',
#   'RPG',
#   '앞서 해보기',
#   '3D',
#   '멀티플레이어',
#   'MMO',
#   '1인칭',
#   '슈팅',
#   '3인칭',
#   '생존',
#   'PvP',
#   '현실적',
#   '1인칭 슈팅',
#   '액션 RPG',
#   '전쟁',
#   '3인칭 슈팅',
#   '전쟁 게임',
#   '총 커스터마이즈',
#   '배틀 로얄'],
#  ['액션',
#   'RPG',
#   '싱글 플레이어',
#   '분위기 있는',
#   '3D',
#   '판타지',
#   '멀티플레이어',
#   '폭력',
#   '전체 이용가',
#   '오픈 월드',
#   '3인칭',
#   '협동',
#   'PvP',
#   '고난이도',
#   '웅장한 사운드트랙',
#   '캐릭터 커스터마이즈',
#   '온라인 협동',
#   '액션 RPG',
#   '다크 판타지',
#   '사운드트랙',
#   '소울라이크',
#   '용',
#   '분위기'],
#  ['액션',
#   '어드벤처',
#   '캐주얼',
#   '시뮬레이션',
#   'RPG',
#   '싱글 플레이어',
#   '풍부한 스토리',
#   '판타지',
#   '귀여운',
#   '누드',
#   '선정적인 내용',
#   '애니메이션',
#   '오픈 월드',
#   '여주인공',
#   '크래프팅',
#   '성인',
#   '턴제',
#   'JRPG',
#   '헨타이',
#   '용'],
#  ['인디',
#   '액션',
#   '어드벤처',
#   'RPG',
#   '싱글 플레이어',
#   '앞서 해보기',
#   '멀티플레이어',
#   'MMO',
#   '1인칭',
#   '공상과학',
#   '오픈 월드',
#   '협동',
#   '생존',
#   '샌드박스',
#   '건설',
#   '크래프팅',
#   '기지 건설',
#   '과학',
#   '용',
#   '오픈 월드 생존 제작',
#   '공룡'],
#  ['액션',
#   '어드벤처',
#   'RPG',
#   '싱글 플레이어',
#   '앞서 해보기',
#   '멀티플레이어',
#   '탐험',
#   '귀여운',
#   '1인칭',
#   '유머',
#   '공포',
#   '오픈 월드',
#   '3인칭',
#   '협동',
#   '생존',
#   '온라인 협동',
#   '샌드박스',
#   '건설',
#   '크래프팅',
#   '기지 건설',
#   '오픈 월드 생존 제작'],
#  ['액션',
#   '어드벤처',
#   'RPG',
#   '싱글 플레이어',
#   '3D',
#   '판타지',
#   '멀티플레이어',
#   '1인칭',
#   '슈팅',
#   '협동',
#   '양식화된',
#   '코미디',
#   '1인칭 슈팅',
#   '캐릭터 커스터마이즈',
#   '온라인 협동',
#   'PvE',
#   '로컬 협동',
#   '내레이션',
#   '약탈',
#   '클래스 기반',
#   '약탈 슈팅'],
#  ['액션', '캐주얼', '스포츠']]

# %%
popular=driver.find_elements(By.CSS_SELECTOR,"#search_resultsRows")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 popular=driver.find_elements(By.CSS_SELECTOR,"#search_resultsRows")
#
# NameError: name 'driver' is not defined

# %%
pop_list=list(map(lambda x : x.text.split('\n'),popular))

# %%
pop_list
# Out:
# [['PUBG: BATTLEGROUNDS',
#   '2017년 12월 21일',
#   '무료',
#   '콜 오브 듀티®: 모던 워페어 II 2022',
#   '2022년 10월 28일',
#   '₩ 84,500',
#   'Apex 레전드™',
#   '2020년 11월 5일',
#   '무료',
#   '데이브 더 다이버',
#   '2022년 10월 27일',
#   '-10%',
#   '₩ 24,000',
#   '₩ 21,600',
#   'Football Manager 2023',
#   '2022년 11월 8일',
#   '-20%',
#   '₩ 59,000',
#   '₩ 47,200',
#   'Cyberpunk 2077',
#   '2020년 12월 10일',
#   '₩ 66,000',
#   'FreestyleFootball R',
#   '2022년 9월 14일',
#   '무료',
#   'GrandChase',
#   '2021년 7월 28일',
#   '무료',
#   'EZ2ON REBOOT : R',
#   '2022년 4월 14일',
#   '₩ 44,800',
#   'V Rising',
#   '2022년 5월 17일',
#   '-20%',
#   '₩ 20,500',
#   '₩ 16,400',
#   'Victoria 3',
#   '2022년 10월 26일',
#   '₩ 52,000',
#   'EZ2ON REBOOT : R - GROOVE COASTER Collaboration DLC',
#   '2022년 10월 31일',
#   '-10%',
#   '₩ 16,500',
#   '₩ 14,850',
#   'EA SPORTS™ FIFA 23',
#   '2022년 9월 30일',
#   '₩ 77,000',
#   'Project Zomboid',
#   '2013년 11월 9일',
#   '₩ 20,500',
#   'War Thunder',
#   'VR 지원',
#   '2013년 8월 15일',
#   '무료',
#   'Rust',
#   '2018년 2월 9일',
#   '-33%',
#   '₩ 46,000',
#   '₩ 30,820',
#   'Dead by Daylight',
#   '2016년 6월 15일',
#   '₩ 21,000',
#   'Red Dead Redemption 2',
#   '2019년 12월 6일',
#   '₩ 66,000',
#   'Mount & Blade II: Bannerlord',
#   '2022년 10월 25일',
#   '-20%',
#   '₩ 55,000',
#   '₩ 44,000',
#   '데스티니 가디언즈',
#   '2019년 10월 2일',
#   '무료',
#   'Grand Theft Auto V',
#   '2015년 4월 14일',
#   'Biohazard Village',
#   '2021년 5월 8일',
#   '₩ 48,400',
#   '페르소나 5 더 로열',
#   '2022년 10월 21일',
#   '₩ 69,800',
#   '토치라이트:인피니트',
#   '2022년 10월 11일',
#   '무료',
#   'The Forest',
#   'VR 지원',
#   '2018년 5월 1일',
#   '₩ 20,500',
#   'Romance of the Three Kingdoms XI with Power Up Kit',
#   '2018년 1월 17일',
#   '-66%',
#   '₩ 41,000',
#   '₩ 13,940',
#   'RimWorld',
#   '2018년 10월 17일',
#   '₩ 36,000',
#   'Yu-Gi-Oh! Master Duel',
#   '2022년 1월 19일',
#   '무료',
#   '니디 걸 오버도즈 : NEEDY GIRL OVERDOSE',
#   '2022년 1월 21일',
#   '-20%',
#   '₩ 16,500',
#   '₩ 13,200',
#   '라이자의 아틀리에2 ~잃어버린 전승과 비밀의 요정~',
#   '2021년 1월 26일',
#   '-50%',
#   '₩ 64,800',
#   '₩ 32,400',
#   'The Sims™ 4',
#   '2020년 6월 19일',
#   '무료',
#   '소울워커',
#   '2022년 3월 17일',
#   '무료',
#   'Heroes of Hammerwatch',
#   '2018년 3월 2일',
#   '₩ 12,500',
#   'Counter-Strike: Global Offensive',
#   '2012년 8월 22일',
#   '무료',
#   'Against the Storm',
#   '2022년 11월 1일',
#   '-15%',
#   '₩ 19,900',
#   '₩ 16,910',
#   'Warframe',
#   '2013년 3월 26일',
#   '무료',
#   'Brotato',
#   '2022년 9월 28일',
#   '₩ 5,500',
#   'SUPER PEOPLE',
#   '2022년 10월 9일',
#   '무료',
#   'RimWorld - Biotech',
#   '2022년 10월 21일',
#   '₩ 27,000',
#   'Backpack Hero',
#   '2022년 8월 16일',
#   '₩ 17,500',
#   'Phasmophobia',
#   'VR 지원',
#   '2020년 9월 19일',
#   '₩ 14,500',
#   '트라하 글로벌',
#   '2022년 11월 2일',
#   '무료',
#   'Inscryption',
#   '2021년 10월 20일',
#   '-40%',
#   '₩ 22,000',
#   '₩ 13,200',
#   '타워 오브 판타지',
#   '2022년 10월 20일',
#   '무료',
#   'The Witcher® 3: Wild Hunt',
#   '2015년 5월 18일',
#   '₩ 34,800',
#   'The Binding of Isaac: Rebirth',
#   '2014년 11월 5일',
#   '₩ 15,500',
#   'ELDEN RING',
#   '2022년 2월 25일',
#   '₩ 64,800',
#   '마블스냅',
#   '2022년 10월 18일',
#   '무료',
#   "Tom Clancy's Rainbow Six® Siege",
#   '2015년 12월 2일',
#   '₩ 22,000',
#   'Dying Light',
#   '2016년 4월 22일',
#   '₩ 34,800']]

# %%
many=[]
for i in popular2:
    if "%" in i[2]:
        del i[2]
