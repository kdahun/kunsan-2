# %%
from select import select
from tkinter import BROWSE
from webbrowser import BaseBrowser
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from webdriver_manager.chrome import ChromeDriverManager

# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains

import time

driver = webdriver.Chrome("./chromedriver")

driver.get('https://store.steampowered.com/charts/mostplayed/')

time.sleep(3)

driver.find_element(By.CSS_SELECTOR,"#language_pulldown").click()
driver.find_element(By.CSS_SELECTOR,"#language_dropdown > div > a:nth-child(4)").click()
# Out:
# C:\Users\dahun\AppData\Local\Temp\ipykernel_17424\388963663.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("./chromedriver")

# %%
popular=driver.find_elements(By.CLASS_NAME,"weeklytopsellers_TableRow_2-RN6")
popular
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9372c5b344c41ed315e36075a7207156", element="811a367a-6a4e-4eb6-9a05-9a00e9ba10b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9372c5b344c41ed315e36075a7207156", element="5ea3121f-13e0-41d6-b710-c9c3a481d33c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9372c5b344c41ed315e36075a7207156", element="0b3a0cc1-27a3-4923-9f6e-6794758aa407")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9372c5b344c41ed315e36075a7207156", element="36eb460b-0d95-4265-aada-252e9f331864")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9372c5b344c41ed315e36075a7207156", element="2e65284e-cc38-497c-8245-9ddf4c624d7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9372c5b344c41ed315e36075a7207156", element="3af6235d-d34e-4bd9-be2e-eca41f243878")>,
# ...

# %%
url=driver.find_elements(By.CLASS_NAME,"weeklytopsellers_TopChartItem_2C5PJ")

# %%
game_url=[]
game_img=[]
for i in url:
    game_url.append(i.get_attribute('href'))
    img=i.find_element(By.TAG_NAME,"img").get_attribute('src')
    req = urllib.request.Request(img, headers = {"User-Agent" : "Mozilla/5.0"})
    res = urllib.request.urlopen(req).read()
    im=Image.open(BytesIO(res))
    game_img=append(im)
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [173], in <cell line: 3>()
#       2 game_img=[]
#       3 for i in url:
# ----> 4     game_url.append(i.get_attribute('href'))
#       5     img=i.find_element(By.TAG_NAME,"img").get_attribute('src')
#       7     req = urllib.request.Request(img, headers = {"User-Agent" : "Mozilla/5.0"})
#
# File ~\Anaconda3\envs\database\lib\site-packages\selenium\webdriver\remote\webelement.py:172, in WebElement.get_attribute(self, name)
#     170 if getAttribute_js is None:
#     171     _load_js()
# --> 172 attribute_value = self.parent.execute_script(
#     173     "return (%s).apply(null, arguments);" % getAttribute_js,
#     174     self, name)
#     175 return attribute_value
#
# File ~\Anaconda3\envs\database\lib\site-packages\selenium\webdriver\remote\webdriver.py:492, in WebDriver.execute_script(self, script, *args)
# ...

# %%
mig=url[0].find_element(By.TAG_NAME,"img")
len(mig)
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [174], in <cell line: 1>()
# ----> 1 mig=url[0].find_element(By.TAG_NAME,"img")
#       2 len(mig)
#
# File ~\Anaconda3\envs\database\lib\site-packages\selenium\webdriver\remote\webelement.py:419, in WebElement.find_element(self, by, value)
#     416     by = By.CSS_SELECTOR
#     417     value = '[name="%s"]' % value
# --> 419 return self._execute(Command.FIND_CHILD_ELEMENT,
#     420                      {"using": by, "value": value})['value']
#
# File ~\Anaconda3\envs\database\lib\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# ...

# %%
len(mig.text())
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [177], in <cell line: 1>()
# ----> 1 len(mig.text())
#
# File ~\Anaconda3\envs\database\lib\site-packages\selenium\webdriver\remote\webelement.py:84, in WebElement.text(self)
#      81 @property
#      82 def text(self) -> str:
#      83     """The text of the element."""
# ---> 84     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#
# File ~\Anaconda3\envs\database\lib\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\Anaconda3\envs\database\lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
# ...

# %%
ll=mig.get_attribute('src')

# %%
from PIL import Image
import urllib.request
import time
from io import BytesIO

# %%
req = urllib.request.Request(ll, headers = {"User-Agent" : "Mozilla/5.0"})
res = urllib.request.urlopen(req).read()
lll=Image.open(BytesIO(res))

# %%
lll
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=231x87>

# %%
game_url
# Out:
# ['https://store.steampowered.com/app/730/CounterStrike_Global_Offensive?snr=1_7001_7005__7003',
#  'https://store.steampowered.com/app/570/Dota_2?snr=1_7001_7005__7003',
#  'https://store.steampowered.com/app/1599340/Lost_Ark?snr=1_7001_7005__7003',
#  'https://store.steampowered.com/app/1938090/_____II_2022?snr=1_7001_7005__7003',
#  'https://store.steampowered.com/app/1172470/Apex?snr=1_7001_7005__7003',
#  'https://store.steampowered.com/app/578080/PUBG_BATTLEGROUNDS?snr=1_7001_7005__7003',
#  'https://store.steampowered.com/app/440/Team_Fortress_2?snr=1_7001_7005__7003',
#  'https://store.steampowered.com/app/1063730/New_World?snr=1_7001_7005__7003',
#  'https://store.steampowered.com/app/431960/Wallpaper_Engine?snr=1_7001_7005__7003',
#  'https://store.steampowered.com/app/271590/Grand_Theft_Auto_V?snr=1_7001_7005__7003',
#  'https://store.steampowered.com/app/252490/Rust?snr=1_7001_7005__7003',
#  'https://store.steampowered.com/app/304930/Unturned?snr=1_7001_7005__7003',
# ...

# %%
popular2=list(map(lambda x : x.text.split('\n'),popular))

# %%
import attrs

# %%
for i in url:
    href = i.attrs['href']
    print(href)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [137], in <cell line: 1>()
#       1 for i in url:
# ----> 2     href = i.attrs['href']
#       3     print(href)
#
# AttributeError: 'WebElement' object has no attribute 'attrs'

# %%
popular2
# Out:
# [['1', 'Counter-Strike: Global Offensive', '무료 플레이', '955,659 1,103,567'],
#  ['2', 'Dota 2', '무료 플레이', '733,792 902,168'],
#  ['3', 'PUBG: BATTLEGROUNDS', '무료 플레이', '391,603 419,894'],
#  ['4', 'Apex 레전드™', '무료 플레이', '348,569 374,295'],
#  ['5',
#   'Grand Theft Auto V',
#   '-25%',
#   '₩ 44,000',
#   '₩ 33,000',
#   '122,678 151,621'],
#  ['6', 'NARAKA: BLADEPOINT', '₩ 22,500', '120,416 143,421'],
#  ['7', '콜 오브 듀티®: 모던 워페어 II 2022', '₩ 84,500', '113,670 193,510'],
#  ['8', 'Wallpaper Engine', '₩ 4,500', '104,699 114,299'],
#  ['9', 'Team Fortress 2', '무료 플레이', '99,285 109,899'],
#  ['10', 'New World', '₩ 41,000', '64,964 121,904'],
#  ['11', 'Rust', '₩ 46,000', '64,816 107,330'],
#  ['12',
#   'Sid Meier’s Civilization® VI',
#   '-90%',
#   '₩ 65,000',
#   '₩ 6,500',
#   '63,783 79,688'],
#  ['13', 'War Thunder', '무료 플레이', '57,667 79,341'],
#  ['14', 'Football Manager 2023', '₩ 59,000', '56,506 75,965'],
#  ['15', 'Unturned', '무료 플레이', '56,137 61,485'],
# ...

# %%
many=[]
for i in popular2:
    if "%" in i[2]:
        del i[2]

# %%
for i in popular2:
    if "₩ " in i[2]:
        del i[2]

# %%
for i in popular2:
    if "₩ " in i[2]:
        del i[2]

# %%
for i in popular2:
    if "무료" in i[2]:
        del i[2]

# %%
for i in popular2:
    if "귀하" in i[2]:
        del i[2]

# %%
for i in popular2:
    i[2]=i[2].split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
#       1 for i in popular2:
# ----> 2     i[2]=i[2].split()
#       3 many
#
# AttributeError: 'list' object has no attribute 'split'

# %%
many
# Out:
# []

# %%
import pandas as pd

# %%
num=[]
name=[]
now=[]
past=[]
for i in popular2:
    num.append(i[0])
    name.append(i[1])
    now.append(i[2][0])
    past.append(i[2][1])

# %%
past
# Out:
# ['1,103,567',
#  '902,168',
#  '276,579',
#  '193,510',
#  '375,729',
#  '109,899',
#  '425,446',
#  '121,904',
#  '107,330',
#  '151,621',
#  '114,299',
#  '61,485',
#  '50,336',
#  '79,688',
#  '75,198',
#  '43,758',
#  '61,409',
#  '79,341',
#  '48,289',
#  '37,792',
#  '51,337',
#  '51,541',
#  '35,036',
#  '44,892',
#  '65,931',
#  '44,209',
#  '75,965',
#  '39,029',
#  '30,683',
#  '53,773',
#  '35,817',
#  '52,404',
#  '34,757',
#  '41,126',
#  '33,831',
#  '144,619',
#  '37,303',
#  '28,804',
#  '40,950',
#  '52,252',
#  '38,849',
#  '26,522',
#  '26,090',
#  '39,548',
#  '22,209',
#  '29,869',
#  '30,211',
#  '24,346',
#  '24,041',
#  '31,273',
#  '24,956',
#  '25,562',
#  '29,608',
#  '23,881',
#  '28,949',
#  '19,876',
#  '28,137',
#  '15,152',
#  '22,016',
#  '19,361',
#  '38,835',
#  '40,244',
#  '20,880',
#  '19,914',
#  '18,018',
#  '27,903',
#  '16,943',
#  '13,508',
#  '17,655',
#  '18,929',
#  '17,464',
#  '16,777',
#  '17,288',
#  '18,854',
#  '19,555',
# ...

# %%
for i in popular2:
    
    print(len(i),i[0])
# Out:
# 4 1
# 4 2
# 4 3
# 4 4
# 4 5
# 4 6
# 4 7
# 4 8
# 4 9
# 4 10
# 4 11
# 4 12
# 4 13
# 4 14
# 4 15
# 4 16
# 4 17
# 4 18
# 4 19
# 4 20
# 4 21
# 4 22
# 4 23
# 4 24
# 4 25
# 4 26
# 4 27
# 4 28
# 4 29
# 4 30
# 4 31
# 4 32
# 4 33
# 3 34
# 4 35
# 4 36
# 4 37
# 4 38
# 4 39
# 4 40
# 4 41
# 4 42
# 4 43
# 4 44
# 4 45
# 5 46
# 4 47
# 5 48
# 4 49
# 4 50
# 4 51
# 4 52
# 4 53
# 4 54
# 4 55
# 4 56
# 4 57
# 4 58
# 4 59
# 5 60
# 4 61
# 4 62
# 4 63
# 4 64
# 4 65
# 3 66
# 4 67
# 5 68
# 4 69
# 4 70
# 4 71
# 4 72
# 4 73
# 4 74
# 4 75
# 4 76
# 4 77
# 5 78
# 4 79
# 4 80
# 5 81
# 5 82
# 4 83
# 4 84
# 3 85
# 4 86
# 4 87
# 4 88
# 5 89
# 4 90
# 4 91
# 4 92
# 5 93
# 4 94
# 4 95
# 4 96
# 4 97
# 4 98
# 5 99
# 4 100

# %%
data={'이름':name,'현재 플레이어':now,'오늘의 최다 동시 접속자 수':past,'url':game_url}
frame=pd.DataFrame(data)

# %%
frame
# Out:
#                                   이름  현재 플레이어 오늘의 최다 동시 접속자 수  \
# 0   Counter-Strike: Global Offensive  418,557       1,103,567
# 1                             Dota 2  316,241         902,168
# 2                           Lost Ark  246,403         276,579
# 3           콜 오브 듀티®: 모던 워페어 II 2022  176,088         193,510
# 4                          Apex 레전드™  114,857         375,729
# ..                               ...      ...             ...
# 95                        The Forest    8,038          21,530
# 96                     Geometry Dash    7,815          13,835
# 97                           소닉 프론티어    7,802           9,480
# 98          American Truck Simulator    7,662           9,542
# 99              Tactics Ogre: Reborn    7,235          10,677
#
#                                                   url
# 0   https://store.steampowered.com/app/730/Counter...
# 1   https://store.steampowered.com/app/570/Dota_2?...
# 2   https://store.steampowered.com/app/1599340/Los...
# ...
